# %% [markdown]
# # Problem 2

# %% [markdown]
# In this Jupyter notebook, we visualize how HMMs work. This visualization corresponds to problem 2 in set 6.
#
# Assuming your HMM module is complete and saved at the correct location, you can simply run all cells in the notebook without modification.

# %%
import os
import numpy as np
from IPython.display import HTML
import json
from HMM import unsupervised_HMM
from HMM_helper import (
    text_to_wordcloud,
    states_to_wordclouds,
    parse_observations,
    sample_sentence,
    visualize_sparsities,
    animate_emission
)
import re
import sys
import random

# %%
text = open(os.path.join(os.getcwd(), 'data_Shakespeare/shakespeare.txt')).read()
obs, obs_map = parse_observations(text)

# %% [markdown]
# ## Visualization of the dataset

# %% [markdown]
# We will be using the Constitution as our dataset. First, we visualize the entirety of the Constitution as a wordcloud:

# %%
text = open(os.path.join(os.getcwd(), 'data_Shakespeare/shakespeare.txt')).read()
wordcloud = text_to_wordcloud(text, title='Shakespeare')

# %% [markdown]
# ## Training an HMM

# %% [markdown]
# Now we train an HMM on our dataset. We use 10 hidden states and train over 100 iterations:

# %%
obs, obs_map = parse_observations(text)
hmm8 = unsupervised_HMM(obs, 10, 100)
# Out:
# Iteration: 10
# Iteration: 20
# Iteration: 30
# Iteration: 40
# Iteration: 50
# Iteration: 60
# Iteration: 70
# Iteration: 80
# Iteration: 90
# Iteration: 100

# %% [markdown]
# ## Part G: Visualization of the sparsities of A and O

# %% [markdown]
# We can visualize the sparsities of the A and O matrices by treating the matrix entries as intensity values and showing them as images. What patterns do you notice?

# %%
test = " How can they make an all-female \
Lord of the Flies if gender is just a social construct?"
letters_only_text = re.sub(r"^[a-z A-Z]", " ", test)
letters_only_text
# Out:
# ' How can they make an all-female Lord of the Flies if gender is just a social construct?'

# %%
visualize_sparsities(hmm8, O_max_cols=50)

# %% [markdown]
# ## Generating a sample sentence

# %% [markdown]
# As you have already seen, an HMM can be used to generate sample sequences based on the given dataset. Run the cell below to show a sample sentence based on the Constitution.

# %%
print('Sample Sentence:\n====================')
print(sample_sentence(hmm8, obs_map, n_words=10))
# Out:
# Sample Sentence:
# ====================
# Whose hath those in foist not odour doth life indeed...

# %%
# Writing sonnet 
for i in range(0, 14):    
    print(sample_sentence(hmm8, obs_map, n_words=8))
# Out:
# Straying receives and way would page in loss...
# Erst thence you cruel believed play his wilt...
# Wood might self invoked child writ do self...
# Not of more cheek therein i knowst that...
# A top lacking her oaths the a can...
# Tired correction nourished from bastard face that love...
# I writ jacks thy enforced not to still...
# Is thine length sight is bid skill my...
# Much make we this grace the and eyes...
# And of and part the by the tired...
# Shame delivered when doth what new you that...
# Tired is thou pen shall still in happy...
# Appear fountains wooed dearths my pity disgrace disgrace...
# Is alone thy wild ill put my be...

# %%
# Writing sonnet 
for i in range(0, 14):    
    print(sample_sentence(hmm10, obs_map, n_words=8))
# Out:
# Desert o'er my thence most as when three...
#  men length the pricked but and least...
# Words mine as all swift-footed this spoils than...
# Knows or dead full prouder good black at...
# Costly tell is young where for to you...
# Am be hold then hear of against joy...
# Like time basest the i of the me...
# Virtue variation these not hast besides white so...
# Monuments in to on help you and be...
# I'll and preserve vouchsafe verse your might out...
# Sing stay dwell in soil the more can...
# My blessings graces i part rage which the...
# Behold not for i the then feeds that...
# But hate your swear are they from welcome...

# %% [markdown]
# ## Part H: Using varying numbers of hidden states

# %% [markdown]
# Using different numbers of hidden states can lead to different behaviours in the HMMs. Below, we train several HMMs with 1, 2, 4, and 16 hidden states, respectively. What do you notice about their emissions? How do these emissions compare to the emission above?

# %%
hmm1 = unsupervised_HMM(obs, 1, 100)
print('\nSample Sentence:\n====================')
# print(sample_sentence1(hmm1, obs_map,"bright", n_words=10)) # for rhyming 
print(sample_sentence(hmm1, obs_map, n_words=25))
# Out:
# Iteration: 10
# Iteration: 20
# Iteration: 30
# Iteration: 40
# Iteration: 50
# Iteration: 60
# Iteration: 70
# Iteration: 80
# Iteration: 90
# Iteration: 100
#
# Sample Sentence:
# ====================
# Of triumph even from once of female esteeming, can you, hath good in bath thou not which believe looking foes but pardon new-fired, in...

# %%
hmm4 = unsupervised_HMM(obs, 4, 100)
# Out:
# Iteration: 10
# Iteration: 20
# Iteration: 30
# Iteration: 40
# Iteration: 50
# Iteration: 60
# Iteration: 70
# Iteration: 80
# Iteration: 90
# Iteration: 100

# %%
find_top_10(hmm4, 3, obs_map)
# Out:
# ['my',
#  'thy',
#  'thou',
#  'to',
#  'the',
#  'i',
#  'thee',
#  'me',
#  'not',
#  'and',
#  'it',
#  'his',
#  'your',
#  'doth',
#  'this']

# %%
wordclouds = states_to_wordclouds(hmm4, obs_map)

# %%
# Testing 4-hidden-states HMM poem generation 
for i in range(0, 14):    
    print(sample_sentence(hmm4, obs_map, n_words=8))
# Out:
# Lust ugly their but to and age's so...
# Pity my shamed thinking first thou you sake...
# Shall in beyond thee the made eye all...
# Be untainted but more this thee and for...
# Lace spite on he love had she so...
# His but tend me why my with do...
# Drawn of shows eye of where let each...
# That make youth that boy thy in speak...
# All-tyrant the thine your me and were by...
# Doom of stormy heart and strength without such...
# That to my and my to help life...
# Well i sound is sky thief torture the...
# It name sweetest one to threescore wished picture...
# By self-substantial descriptions too like long their she...

# %%
hmm16 = unsupervised_HMM(obs, 16, 100)
print('\nSample Sonnet:\n====================')
# Out:
# Iteration: 10
# Iteration: 20
# Iteration: 30
# Iteration: 40
# Iteration: 50
# Iteration: 60
# Iteration: 70
# Iteration: 80
# Iteration: 90
# Iteration: 100
#
# Sample Sentence:
# ====================
# And is your plague forbear must all my...
# Nor it eyes for none presentabsent thy beauty...
# Hate mock to fortune antiquity and doth bear...
# Bear wards thy will thee fault pursuit assured...
# Or yet to of counting cool thorns be...
# Such am thoughts thee cunning by the gives...
# With tires man can divided lame like general...
# Me is more barren waiting as make inconstant...
# Slay watchman but me by growing thine see...
# Man name it mistaking my self at that...
# Believe in beauty presents song be to that...
# So pale replete have swift thy gift yours...
# Straight are this place outlive prescriptions are to...
# Is conquest me next near who esteem give...

# %%
# Writing sonnet 
for i in range(0, 14):    
    print(sample_sentence(hmm16, obs_map, n_words=8))
#print(sample_sentence(hmm16, obs_map, n_words=25))
# Out:
# Either graces this winds fair to hath my...
# That prove in so seeing from i ending...
# Divide their his most art false and eclipse...
# To knew fresh aspect more life decay himself...
# Like like of sweet that and up from...
# Among in they do allow seem your where...
# And and how with stand with mine say...
# Do my heart still and strangely even and...
# Are old seeming less making new scorned tombs...
# Even merit which form to debarred thousand cherubins...
# With dun so perfection is one was i...
# So when why that is come forbid looks...
# For my wished spirits to doth presence do...
# Privilage sullied i or heaven to griefs and...

# %%
hmm20 = unsupervised_HMM(obs, 20, 100)
print('\nSample Sonnet, 20 Latent States:\n====================')
# Writing sonnet 
for i in range(0, 14):    
    print(sample_sentence(hmm20, obs_map, n_words=10))
# Out:
# Iteration: 10
# Iteration: 20
# Iteration: 30
# Iteration: 40
# Iteration: 50
# Iteration: 60
# Iteration: 70
# Iteration: 80
# Iteration: 90
# Iteration: 100
#
# Sample Sonnet, 20 Latent States:
# ====================
# And that so of fuel dial wilt before beauty to...
# Nothing onwards worth brought to former thoughts not conscience be...
# For keep be bending the remembrance with thine for he...
# The thou created rank thee my beast thy love being...
# Neercloying grave annexed make pace are base to th is...
# Again with hides the expired of after powers compare i...
# But eyes in far defect kept his hell mend up...
# Breast doth it i with the but rhyme by shalt...
# Ill thou so times one of profaned resort and many...
# Shows a shape nor what the heals other of you...
# Arts that hold now not compare grace woo of a...
# Love then he thine fortify nature saturn nimble tongue where...
# Sweet leave by their minds decays his as heard of...
# Thy my pleasure out proud and and decease every thy...

# %%
# Writing sonnet 
for i in range(0, 14):    
    print(sample_sentence(hmm20, obs_map, n_words=8))
# Out:
# Be in when do the up two with...
# Verse beseechers cover dost i night the is...
# Away had cannot lies her or leese thou...
# Then strength body's a to by give is...
# Wretch too gate i upon liker assured sweet...
# Proud forbear me to all all in how...
# Pale those to saucy coward no april laid...
# Loved impediments flowers calls she why sun i...
# Heart beauty world's thou therefore from of were...
# Show distempered of are no when disgrace a...
#  use grieve they like spirit always i...
# And epitaph your who which with bond less...
# A a thee seasons' without true foregone i...
# Him flourish profitless earth self-doing send'st the for...

# %% [markdown]
# ## Part I: Visualizing the wordcloud of each state

# %% [markdown]
# Below, we visualize each state as a wordcloud by sampling a large emission from the state:

# %%
wordclouds = states_to_wordclouds(hmm8, obs_map)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-93-982d2b1b796b> in <module>()
# ----> 1 wordclouds = states_to_wordclouds(hmm8, obs_map)
#
# ~/Desktop/cs155project3/solution/HMM_helper.py in states_to_wordclouds(hmm, obs_map, max_words, show)
#      72     for i in range(n_states):
#      73         obs_lst = obs_count[i]
# ---> 74         sentence = [obs_map_r[j] for j in obs_lst]
#      75         sentence_str = ' '.join(sentence)
#      76
#
# ~/Desktop/cs155project3/solution/HMM_helper.py in <listcomp>(.0)
#      72     for i in range(n_states):
#      73         obs_lst = obs_count[i]
# ---> 74         sentence = [obs_map_r[j] for j in obs_lst]
#      75         sentence_str = ' '.join(sentence)
#      76
#
# KeyError: 3286

# %% [markdown]
# ## Visualizing the process of an HMM generating an emission

# %% [markdown]
# The visualization below shows how an HMM generates an emission. Each state is shown as a wordcloud on the plot, and transition probabilities between the states are shown as arrows. The darker an arrow, the higher the transition probability.
#
# At every frame, a transition is taken and an observation is emitted from the new state. A red arrow indicates that the transition was just taken. If a transition stays at the same state, it is represented as an arrowhead on top of that state.
#
# Use fullscreen for a better view of the process.

# %%
anim = animate_emission(hmm8, obs_map, M=8)
HTML(anim.to_html5_video())
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/cbook/__init__.py:424: MatplotlibDeprecationWarning:
# Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warn_deprecated("2.2", "Passing one of 'on', 'true', 'off', 'false' as a "
# Animating...
# <video width="864" height="864" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# # Training Character-Based LSTM

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.callbacks import ModelCheckpoint
from keras.utils import np_utils
from keras.layers import Lambda

# %%
text = open(os.path.join(os.getcwd(), 'data_Shakespeare/shakespeare.txt')).read()

# %%
 # Convert text to dataset.
lines = [line.split() for line in text.split('\n') if line.split()]
allwords = []

for line in lines:
    obs_elem = []

    for word in line:
        word = word.strip()
        if word.isdigit() == False:
            # through out all digits
            word = re.sub(r'[^\w\?\-\'\,]', '', word).lower() 
            allwords.append(word)

# %%
# Saving stripped version as textfile
with open('ShakespeareChars3.txt', 'w') as f:
    for words in allwords:
        f.write('%s ' % words)
        
f.close()

# %%
filename = 'ShakespeareChars1.txt'
raw_text = open(filename, 'r', encoding='utf-8').read()
raw_text = raw_text.lower()

# %%
# create mapping of unique chars to integers
chars = sorted(list(set(raw_text)))
char_to_int = dict((c, i) for i, c in enumerate(chars))

# %%
n_chars = len(raw_text)
n_vocab = len(chars)
print("Total Characters: ", n_chars)
print("Total Vocab: ", n_vocab)
# Out:
# Total Characters:  92978
# Total Vocab:  31

# %%
X = []
Y = []

# %%
# prepare the dataset of input to output pairs encoded as integers
seq_length = 40
dataX = []
dataY = []
for i in range(0, n_chars - seq_length, 3):
    seq_in = raw_text[i:i + seq_length]
    seq_out = raw_text[i + seq_length]
    dataX.append([char_to_int[char] for char in seq_in])
    dataY.append(char_to_int[seq_out])
n_patterns = len(dataX)
print("Total Patterns: ", n_patterns)
# Out:
# Total Patterns:  30980

# %%
# reshape X to be [samples, time steps, features]
#X = np.reshape(dataX, (n_patterns, seq_length, 1))

X = np_utils.to_categorical(dataX)
# one hot encode the output variable
y = np_utils.to_categorical(dataY)

# %% [markdown]
# # LSTM with Temperature

# %%
# For temperature parameter: model.add(Lambda(lambda x: x / temp_val)) 
model = Sequential()
model.add(LSTM(150, input_shape=(X.shape[1], X.shape[2])))

model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Check-pointing the training to allow us to pinpoint the lowest-loss model
filepath="weights-improvement-{epoch:02d}-{loss:.4f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

# %%
# Training
model.fit(X, y, epochs=50, batch_size=16, callbacks=callbacks_list)
# Out:
# Epoch 1/50
# 30980/30980 [==============================] - 66s 2ms/step - loss: 2.4021 - acc: 0.3098
#
# Epoch 00001: loss improved from inf to 2.40213, saving model to weights-improvement-01-2.4021.hdf5
# Epoch 2/50
# 30980/30980 [==============================] - 73s 2ms/step - loss: 2.0173 - acc: 0.4023
#
# Epoch 00002: loss improved from 2.40213 to 2.01732, saving model to weights-improvement-02-2.0173.hdf5
# Epoch 3/50
# 30980/30980 [==============================] - 73s 2ms/step - loss: 1.8702 - acc: 0.4368
#
# Epoch 00003: loss improved from 2.01732 to 1.87018, saving model to weights-improvement-03-1.8702.hdf5
# Epoch 4/50
# 30980/30980 [==============================] - 65s 2ms/step - loss: 1.7734 - acc: 0.4558
#
# Epoch 00004: loss improved from 1.87018 to 1.77342, saving model to weights-improvement-04-1.7734.hdf5
# Epoch 5/50
# 30980/30980 [==============================] - 66s 2ms/step - loss: 1.6941 - acc: 0.4781
#
# Epoch 00005: loss improved from 1.77342 to 1.69405, saving model to weights-improvement-05-1.6941.hdf5
# Epoch 6/50
# 30980/30980 [==============================] - 64s 2ms/step - loss: 1.6254 - acc: 0.4965
#
# Epoch 00006: loss improved from 1.69405 to 1.62543, saving model to weights-improvement-06-1.6254.hdf5
# Epoch 7/50
# 30980/30980 [==============================] - 68s 2ms/step - loss: 1.5572 - acc: 0.5139
#
# Epoch 00007: loss improved from 1.62543 to 1.55723, saving model to weights-improvement-07-1.5572.hdf5
# Epoch 8/50
# 30980/30980 [==============================] - 69s 2ms/step - loss: 1.4877 - acc: 0.5331
#
# Epoch 00008: loss improved from 1.55723 to 1.48774, saving model to weights-improvement-08-1.4877.hdf5
# Epoch 9/50
# 30980/30980 [==============================] - 66s 2ms/step - loss: 1.4182 - acc: 0.5529
#
# Epoch 00009: loss improved from 1.48774 to 1.41822, saving model to weights-improvement-09-1.4182.hdf5
# Epoch 10/50
# 30980/30980 [==============================] - 63s 2ms/step - loss: 1.3463 - acc: 0.5745
#
# Epoch 00010: loss improved from 1.41822 to 1.34626, saving model to weights-improvement-10-1.3463.hdf5
# Epoch 11/50
# 30980/30980 [==============================] - 64s 2ms/step - loss: 1.2731 - acc: 0.5968
#
# Epoch 00011: loss improved from 1.34626 to 1.27310, saving model to weights-improvement-11-1.2731.hdf5
# Epoch 12/50
# 30980/30980 [==============================] - 64s 2ms/step - loss: 1.1949 - acc: 0.6226
#
# Epoch 00012: loss improved from 1.27310 to 1.19494, saving model to weights-improvement-12-1.1949.hdf5
# Epoch 13/50
# 30980/30980 [==============================] - 64s 2ms/step - loss: 1.1224 - acc: 0.6445
#
# Epoch 00013: loss improved from 1.19494 to 1.12240, saving model to weights-improvement-13-1.1224.hdf5
# Epoch 14/50
# 30980/30980 [==============================] - 69s 2ms/step - loss: 1.0506 - acc: 0.6642
#
# Epoch 00014: loss improved from 1.12240 to 1.05062, saving model to weights-improvement-14-1.0506.hdf5
# Epoch 15/50
# 30980/30980 [==============================] - 63s 2ms/step - loss: 0.9849 - acc: 0.6881
#
# Epoch 00015: loss improved from 1.05062 to 0.98486, saving model to weights-improvement-15-0.9849.hdf5
# Epoch 16/50
# 30980/30980 [==============================] - 63s 2ms/step - loss: 0.9226 - acc: 0.7097
#
# Epoch 00016: loss improved from 0.98486 to 0.92264, saving model to weights-improvement-16-0.9226.hdf5
# Epoch 17/50
# 30980/30980 [==============================] - 64s 2ms/step - loss: 0.8687 - acc: 0.7274
#
# Epoch 00017: loss improved from 0.92264 to 0.86868, saving model to weights-improvement-17-0.8687.hdf5
# Epoch 18/50
# 30980/30980 [==============================] - 70s 2ms/step - loss: 0.8170 - acc: 0.7402
#
# Epoch 00018: loss improved from 0.86868 to 0.81696, saving model to weights-improvement-18-0.8170.hdf5
# Epoch 19/50
# 30980/30980 [==============================] - 73s 2ms/step - loss: 0.7736 - acc: 0.7586
#
# Epoch 00019: loss improved from 0.81696 to 0.77365, saving model to weights-improvement-19-0.7736.hdf5
# Epoch 20/50
# 30980/30980 [==============================] - 66s 2ms/step - loss: 0.7322 - acc: 0.7703
#
# Epoch 00020: loss improved from 0.77365 to 0.73223, saving model to weights-improvement-20-0.7322.hdf5
# Epoch 21/50
# 30980/30980 [==============================] - 70s 2ms/step - loss: 0.6969 - acc: 0.7812
#
# Epoch 00021: loss improved from 0.73223 to 0.69689, saving model to weights-improvement-21-0.6969.hdf5
# Epoch 22/50
# 30980/30980 [==============================] - 75s 2ms/step - loss: 0.6643 - acc: 0.7896
#
# Epoch 00022: loss improved from 0.69689 to 0.66427, saving model to weights-improvement-22-0.6643.hdf5
# Epoch 23/50
# 30980/30980 [==============================] - 79s 3ms/step - loss: 0.6399 - acc: 0.7974
#
# Epoch 00023: loss improved from 0.66427 to 0.63993, saving model to weights-improvement-23-0.6399.hdf5
# Epoch 24/50
# 30980/30980 [==============================] - 70s 2ms/step - loss: 0.6175 - acc: 0.8031
#
# Epoch 00024: loss improved from 0.63993 to 0.61746, saving model to weights-improvement-24-0.6175.hdf5
# Epoch 25/50
# 30980/30980 [==============================] - 78s 3ms/step - loss: 0.5859 - acc: 0.8151
#
# Epoch 00025: loss improved from 0.61746 to 0.58588, saving model to weights-improvement-25-0.5859.hdf5
# Epoch 26/50
# 30980/30980 [==============================] - 80s 3ms/step - loss: 0.5674 - acc: 0.8206
#
# Epoch 00026: loss improved from 0.58588 to 0.56745, saving model to weights-improvement-26-0.5674.hdf5
# Epoch 27/50
# 30980/30980 [==============================] - 67s 2ms/step - loss: 0.5509 - acc: 0.8236
#
# Epoch 00027: loss improved from 0.56745 to 0.55095, saving model to weights-improvement-27-0.5509.hdf5
# Epoch 28/50
# 30980/30980 [==============================] - 70s 2ms/step - loss: 0.5373 - acc: 0.8314
#
# Epoch 00028: loss improved from 0.55095 to 0.53726, saving model to weights-improvement-28-0.5373.hdf5
# Epoch 29/50
# 30980/30980 [==============================] - 66s 2ms/step - loss: 0.5081 - acc: 0.8399
#
# Epoch 00029: loss improved from 0.53726 to 0.50806, saving model to weights-improvement-29-0.5081.hdf5
# Epoch 30/50
# 30980/30980 [==============================] - 71s 2ms/step - loss: 0.4893 - acc: 0.8471
#
# Epoch 00030: loss improved from 0.50806 to 0.48935, saving model to weights-improvement-30-0.4893.hdf5
# Epoch 31/50
# 30980/30980 [==============================] - 72s 2ms/step - loss: 0.4878 - acc: 0.8445
#
# Epoch 00031: loss improved from 0.48935 to 0.48777, saving model to weights-improvement-31-0.4878.hdf5
# Epoch 32/50
# 30980/30980 [==============================] - 67s 2ms/step - loss: 0.4735 - acc: 0.8520
#
# Epoch 00032: loss improved from 0.48777 to 0.47353, saving model to weights-improvement-32-0.4735.hdf5
# Epoch 33/50
# 30980/30980 [==============================] - 63s 2ms/step - loss: 0.4530 - acc: 0.8550
#
# Epoch 00033: loss improved from 0.47353 to 0.45300, saving model to weights-improvement-33-0.4530.hdf5
# Epoch 34/50
# 30980/30980 [==============================] - 73s 2ms/step - loss: 0.4477 - acc: 0.8566
#
# Epoch 00034: loss improved from 0.45300 to 0.44769, saving model to weights-improvement-34-0.4477.hdf5
# Epoch 35/50
# 30980/30980 [==============================] - 65s 2ms/step - loss: 0.4380 - acc: 0.8598
#
# Epoch 00035: loss improved from 0.44769 to 0.43796, saving model to weights-improvement-35-0.4380.hdf5
# Epoch 36/50
# 30980/30980 [==============================] - 70s 2ms/step - loss: 0.4224 - acc: 0.8674
#
# Epoch 00036: loss improved from 0.43796 to 0.42241, saving model to weights-improvement-36-0.4224.hdf5
# Epoch 37/50
# 30980/30980 [==============================] - 67s 2ms/step - loss: 0.4044 - acc: 0.8736
#
# Epoch 00037: loss improved from 0.42241 to 0.40443, saving model to weights-improvement-37-0.4044.hdf5
# Epoch 38/50
# 26000/30980 [========================>.....] - ETA: 10s - loss: 0.3809 - acc: 0.8798
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-247-dfa8e428606b> in <module>()
#       1 # Training
# ----> 2 model.fit(X, y, epochs=50, batch_size=16, callbacks=callbacks_list)
#
# /anaconda3/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# /anaconda3/lib/python3.6/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# /anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# /anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1380           ret = tf_session.TF_SessionRunCallable(
#    1381               self._session._session, self._handle, args, status,
# -> 1382               run_metadata_ptr)
#    1383         if run_metadata:
#    1384           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
# Recovering the lowest-loss weights 
filename = "weights-improvement-98-0.6485.hdf5"
model.load_weights(filename)
model.compile(loss='categorical_crossentropy', optimizer='adam')

# %%
int_to_char = dict((i, c) for i, c in enumerate(chars))

# %%
pattern = []
# Converting seed to a beginning pattern

seed = "shall i compare thee to a summer's day? "
#“shall i compare thee to a summer’s day?\n”

for c in seed:
    pattern.append(char_to_int[c])

# %% [markdown]
# # LSTM Sentence Generation

# %%
print("Seed:")
print("\"", ''.join([int_to_char[value] for value in pattern]), "\"")
# Out:
# Seed:
# " shall i compare thee to a summer's day?  "

# %%
#start = np.random.randint(0, len(dataX)-1)
#pattern = dataX[start]
print("Seed:")
print("\"", ''.join([int_to_char[value] for value in pattern]), "\"")
# Out:
# Seed:
# " whose shadow shadows doth make bright ho "

# %%
# Starting seed:  shall i compare thee to a summers day


# weights-improvement-87-0.6483.hdf5 (the file you want)
# loss improved from 0.67607 to 0.64828, saving model to weights-improvement-87-0.6483.hdf5
# epoch: 87


# generate characters
for i in range(400):
    x = np.reshape(pattern, (1, len(pattern), 1))
    x = x / float(n_vocab)
    prediction = model.predict(x, verbose=0)
    index = np.argmax(prediction)
    result = int_to_char[index]
    seq_in = [int_to_char[value] for value in pattern]
    sys.stdout.write(result)
    pattern.append(index)
    pattern = pattern[1:len(pattern)]
# Out:
# eeatees dout ary brool n shlle to aeme  fo  tual aootr ii  yhi foottens baaet, lnse,toatket  eede,,blat,,ard braan bwdtlot ban  rhr hoee aadi fo whbr souuru,srsnn honnnt,tolnt,de  nr hes shy pilf fi a an cn oueeu hiant oo heaet s  il gu suue  ldne tee  anlly tft wher mts sy toaf thin oooes' ooeme the  nllly toatoess to mhee  th thald  toer   edddddddeee,aee  yyer heerte  ooieo  aod geak  uoan auat

# %%
for e in dataX:
    
    for i in e:
        print(int_to_char[i], end="")
    print('\n')
# Out:
# from fairest creatures we desire increas
#
# st creatures we desire increase, that th
#
# es we desire increase, that thereby beau
#
# re increase, that thereby beauty's rose
#
# e, that thereby beauty's rose might neve
#
# ereby beauty's rose might never die, but
#
# ty's rose might never die, but as the ri
#
# might never die, but as the riper should
#
# r die, but as the riper should by time d
#
#  as the riper should by time decease, hi
#
# per should by time decease, his tender h
#
#  by time decease, his tender heir might
#
# ecease, his tender heir might bear his m
#
# s tender heir might bear his memory but
#
# eir might bear his memory but thou contr
#
# bear his memory but thou contracted to t
#
# emory but thou contracted to thine own b
#
# thou contracted to thine own bright eyes
#
# acted to thine own bright eyes, feed'st
#
# hine own bright eyes, feed'st thy light'
#
# right eyes, feed'st thy light's flame wi
#
# , feed'st thy light's flame with self-su
#
# thy light's flame with self-substantial
#
# s flame with self-substantial fuel, maki
#
# th self-substantial fuel, making a famin
#
# bstantial fuel, making a famine where ab
#
# fuel, making a famine where abundance li
#
# ng a famine where abundance lies, thy se
#
# e where abundance lies, thy self thy foe
#
# undance lies, thy self thy foe, to thy s
#
# es, thy self thy foe, to thy sweet self
#
# lf thy foe, to thy sweet self too cruel
#
# , to thy sweet self too cruel thou that
#
# weet self too cruel thou that art now th
#
# too cruel thou that art now the world's
#
# thou that art now the world's fresh orna
#
# art now the world's fresh ornament, and
#
# e world's fresh ornament, and only heral
#
# fresh ornament, and only herald to the g
#
# ment, and only herald to the gaudy sprin
#
# only herald to the gaudy spring, within
#
# d to the gaudy spring, within thine own
#
# audy spring, within thine own bud buries
#
# g, within thine own bud buriest thy cont
#
# thine own bud buriest thy content, and t
#
# bud buriest thy content, and tender chur
#
# t thy content, and tender churl mak'st w
#
# ent, and tender churl mak'st waste in ni
#
# ender churl mak'st waste in niggarding p
#
# l mak'st waste in niggarding pity the wo
#
# aste in niggarding pity the world, or el
#
# ggarding pity the world, or else this gl
#
# ity the world, or else this glutton be,
#
# rld, or else this glutton be, to eat the
#
# se this glutton be, to eat the world's d
#
# utton be, to eat the world's due, by the
#
# to eat the world's due, by the grave and
#
#  world's due, by the grave and thee when
#
# ue, by the grave and thee when forty win
#
#  grave and thee when forty winters shall
#
#  thee when forty winters shall besiege t
#
#  forty winters shall besiege thy brow, a
#
# ters shall besiege thy brow, and dig dee
#
#  besiege thy brow, and dig deep trenches
#
# hy brow, and dig deep trenches in thy be
#
# nd dig deep trenches in thy beauty's fie
#
# p trenches in thy beauty's field, thy yo
#
#  in thy beauty's field, thy youth's prou
#
# auty's field, thy youth's proud livery s
#
# ld, thy youth's proud livery so gazed on
#
# uth's proud livery so gazed on now, will
#
# d livery so gazed on now, will be a tatt
#
# o gazed on now, will be a tattered weed
#
#  now, will be a tattered weed of small w
#
#  be a tattered weed of small worth held
#
# ered weed of small worth held then being
#
# of small worth held then being asked, wh
#
# orth held then being asked, where all th
#
# then being asked, where all thy beauty l
#
#  asked, where all thy beauty lies, where
#
# ere all thy beauty lies, where all the t
#
# y beauty lies, where all the treasure of
#
# ies, where all the treasure of thy lusty
#
#  all the treasure of thy lusty days to s
#
# reasure of thy lusty days to say within
#
#  thy lusty days to say within thine own
#
#  days to say within thine own deep sunke
#
# ay within thine own deep sunken eyes, we
#
# thine own deep sunken eyes, were an all-
#
# deep sunken eyes, were an all-eating sha
#
# n eyes, were an all-eating shame, and th
#
# re an all-eating shame, and thriftless p
#
# eating shame, and thriftless praise how
#
# me, and thriftless praise how much more
#
# riftless praise how much more praise des
#
# raise how much more praise deserved thy
#
# much more praise deserved thy beauty's u
#
# praise deserved thy beauty's use, if tho
#
# erved thy beauty's use, if thou couldst
#
# beauty's use, if thou couldst answer 'th
#
# se, if thou couldst answer 'this fair ch
#
# u couldst answer 'this fair child of min
#
# answer 'this fair child of mine shall su
#
# is fair child of mine shall sum my count
#
# ild of mine shall sum my count, and make
#
# e shall sum my count, and make my old ex
#
# m my count, and make my old excuse' prov
#
# , and make my old excuse' proving his be
#
#  my old excuse' proving his beauty by su
#
# cuse' proving his beauty by succession t
#
# ing his beauty by succession thine this
#
# auty by succession thine this were to be
#
# ccession thine this were to be new made
#
# hine this were to be new made when thou
#
# were to be new made when thou art old, a
#
#  new made when thou art old, and see thy
#
# when thou art old, and see thy blood war
#
# art old, and see thy blood warm when tho
#
# nd see thy blood warm when thou feel'st
#
#  blood warm when thou feel'st it cold lo
#
# m when thou feel'st it cold look in thy
#
# u feel'st it cold look in thy glass and
#
# it cold look in thy glass and tell the f
#
# ok in thy glass and tell the face thou v
#
# glass and tell the face thou viewest, no
#
# tell the face thou viewest, now is the t
#
# ace thou viewest, now is the time that f
#
# iewest, now is the time that face should
#
# w is the time that face should form anot
#
# ime that face should form another, whose
#
# ace should form another, whose fresh rep
#
#  form another, whose fresh repair if now
#
# her, whose fresh repair if now thou not
#
#  fresh repair if now thou not renewest,
#
# air if now thou not renewest, thou dost
#
#  thou not renewest, thou dost beguile th
#
# renewest, thou dost beguile the world, u
#
# thou dost beguile the world, unbless som
#
# beguile the world, unbless some mother f
#
# e world, unbless some mother for where i
#
# nbless some mother for where is she so f
#
# e mother for where is she so fair whose
#
# or where is she so fair whose uneared wo
#
# s she so fair whose uneared womb disdain
#
# air whose uneared womb disdains the till
#
# uneared womb disdains the tillage of thy
#
# mb disdains the tillage of thy husbandry
#
# s the tillage of thy husbandry? or who i
#
# age of thy husbandry? or who is he so fo
#
#  husbandry? or who is he so fond will be
#
# ? or who is he so fond will be the tomb,
#
# s he so fond will be the tomb, of his se
#
# nd will be the tomb, of his self-love to
#
#  the tomb, of his self-love to stop post
#
#  of his self-love to stop posterity? tho
#
# lf-love to stop posterity? thou art thy
#
#  stop posterity? thou art thy mother's g
#
# erity? thou art thy mother's glass and s
#
# u art thy mother's glass and she in thee
#
# mother's glass and she in thee calls bac
#
# lass and she in thee calls back the love
#
# he in thee calls back the lovely april o
#
#  calls back the lovely april of her prim
#
# k the lovely april of her prime, so thou
#
# ly april of her prime, so thou through w
#
# f her prime, so thou through windows of
#
# e, so thou through windows of thine age
#
#  through windows of thine age shalt see,
#
# indows of thine age shalt see, despite o
#
# thine age shalt see, despite of wrinkles
#
# shalt see, despite of wrinkles this thy
#
#  despite of wrinkles this thy golden tim
#
# f wrinkles this thy golden time but if t
#
#  this thy golden time but if thou live r
#
# golden time but if thou live remembered
#
# e but if thou live remembered not to be,
#
# hou live remembered not to be, die singl
#
# emembered not to be, die single and thin
#
# not to be, die single and thine image di
#
#  die single and thine image dies with th
#
# e and thine image dies with thee unthrif
#
# e image dies with thee unthrifty lovelin
#
# es with thee unthrifty loveliness why do
#
# ee unthrifty loveliness why dost thou sp
#
# ty loveliness why dost thou spend, upon
#
# ess why dost thou spend, upon thy self t
#
# st thou spend, upon thy self thy beauty'
#
# end, upon thy self thy beauty's legacy?
#
# thy self thy beauty's legacy? nature's b
#
# hy beauty's legacy? nature's bequest giv
#
# s legacy? nature's bequest gives nothing
#
# nature's bequest gives nothing but doth
#
# equest gives nothing but doth lend, and
#
# es nothing but doth lend, and being fran
#
#  but doth lend, and being frank she lend
#
# lend, and being frank she lends to those
#
# being frank she lends to those are free
#
# k she lends to those are free then beaut
#
# s to those are free then beauteous nigga
#
#  are free then beauteous niggard why dos
#
# then beauteous niggard why dost thou abu
#
# eous niggard why dost thou abuse, the bo
#
# rd why dost thou abuse, the bounteous la
#
# t thou abuse, the bounteous largess give
#
# se, the bounteous largess given thee to
#
# unteous largess given thee to give? prof
#
# rgess given thee to give? profitless usu
#
# n thee to give? profitless usurer why do
#
# give? profitless usurer why dost thou us
#
# itless usurer why dost thou use so great
#
# rer why dost thou use so great a sum of
#
# st thou use so great a sum of sums yet c
#
# e so great a sum of sums yet canst not l
#
#  a sum of sums yet canst not live? for h
#
# sums yet canst not live? for having traf
#
# anst not live? for having traffic with t
#
# ive? for having traffic with thy self al
#
# aving traffic with thy self alone, thou
#
# fic with thy self alone, thou of thy sel
#
# hy self alone, thou of thy self thy swee
#
# one, thou of thy self thy sweet self dos
#
# of thy self thy sweet self dost deceive,
#
# f thy sweet self dost deceive, then how
#
# t self dost deceive, then how when natur
#
# t deceive, then how when nature calls th
#
#  then how when nature calls thee to be g
#
# when nature calls thee to be gone, what
#
# e calls thee to be gone, what acceptable
# ee to be gone, what acceptable audit can
#
# one, what acceptable audit canst thou le
#
# acceptable audit canst thou leave? thy u
#
#  audit canst thou leave? thy unused beau
#
# st thou leave? thy unused beauty must be
#
# ave? thy unused beauty must be tombed wi
#
# nused beauty must be tombed with thee, w
#
# ty must be tombed with thee, which used
#
#  tombed with thee, which used lives th'
#
# th thee, which used lives th' executor t
#
# hich used lives th' executor to be those
#
# lives th' executor to be those hours tha
#
# executor to be those hours that with gen
#
# o be those hours that with gentle work d
#
#  hours that with gentle work did frame t
#
# t with gentle work did frame the lovely
#
# tle work did frame the lovely gaze where
#
# id frame the lovely gaze where every eye
#
# he lovely gaze where every eye doth dwel
#
# gaze where every eye doth dwell will pla
#
#  every eye doth dwell will play the tyra
#
#  doth dwell will play the tyrants to the
#
# l will play the tyrants to the very same
#
# y the tyrants to the very same, and that
#
# nts to the very same, and that unfair wh
#
#  very same, and that unfair which fairly
#
# , and that unfair which fairly doth exce
#
#  unfair which fairly doth excel for neve
#
# ich fairly doth excel for never-resting
#
#  doth excel for never-resting time leads
#
# l for never-resting time leads summer on
#
# r-resting time leads summer on to hideou
#
# time leads summer on to hideous winter a
#
#  summer on to hideous winter and confoun
#
#  to hideous winter and confounds him the
#
# s winter and confounds him there, sap ch
#
# nd confounds him there, sap checked with
#
# ds him there, sap checked with frost and
#
# re, sap checked with frost and lusty lea
#
# ecked with frost and lusty leaves quite
#
#  frost and lusty leaves quite gone, beau
#
#  lusty leaves quite gone, beauty o'er-sn
#
# ves quite gone, beauty o'er-snowed and b
#
# gone, beauty o'er-snowed and bareness ev
#
# ty o'er-snowed and bareness every where
#
# owed and bareness every where then were
#
# areness every where then were not summer
#
# ery where then were not summer's distill
#
# then were not summer's distillation left
#
# not summer's distillation left a liquid
#
# 's distillation left a liquid prisoner p
#
# ation left a liquid prisoner pent in wal
#
#  a liquid prisoner pent in walls of glas
#
# prisoner pent in walls of glass, beauty'
#
# ent in walls of glass, beauty's effect w
#
# ls of glass, beauty's effect with beauty
#
# s, beauty's effect with beauty were bere
#
# s effect with beauty were bereft, nor it
#
# ith beauty were bereft, nor it nor no re
#
#  were bereft, nor it nor no remembrance
#
# ft, nor it nor no remembrance what it wa
#
#  nor no remembrance what it was but flow
#
# membrance what it was but flowers distil
#
# what it was but flowers distilled though
#
# s but flowers distilled though they with
#
# ers distilled though they with winter me
#
# led though they with winter meet, leese
#
#  they with winter meet, leese but their
#
#  winter meet, leese but their show, thei
#
# et, leese but their show, their substanc
#
# but their show, their substance still li
#
# show, their substance still lives sweet
#
# r substance still lives sweet then let n
#
# e still lives sweet then let not winter'
#
# ves sweet then let not winter's ragged h
#
# then let not winter's ragged hand deface
#
# ot winter's ragged hand deface, in thee
#
# s ragged hand deface, in thee thy summer
#
# and deface, in thee thy summer ere thou
#
# , in thee thy summer ere thou be distill
#
# thy summer ere thou be distilled make sw
#
#  ere thou be distilled make sweet some v
#
# be distilled make sweet some vial treasu
#
# ed make sweet some vial treasure thou so
#
# eet some vial treasure thou some place,
#
# ial treasure thou some place, with beaut
#
# re thou some place, with beauty's treasu
#
# me place, with beauty's treasure ere it
#
# with beauty's treasure ere it be self-ki
#
# y's treasure ere it be self-killed that
#
# re ere it be self-killed that use is not
#
# be self-killed that use is not forbidden
#
# lled that use is not forbidden usury, wh
#
# use is not forbidden usury, which happie
#
#  forbidden usury, which happies those th
#
#  usury, which happies those that pay the
#
# ich happies those that pay the willing l
#
# s those that pay the willing loan that's
#
# at pay the willing loan that's for thy s
#
#  willing loan that's for thy self to bre
#
# oan that's for thy self to breed another
#
#  for thy self to breed another thee, or
#
# elf to breed another thee, or ten times
#
# ed another thee, or ten times happier be
#
#  thee, or ten times happier be it ten fo
#
# ten times happier be it ten for one, ten
#
# happier be it ten for one, ten times thy
#
#  it ten for one, ten times thy self were
#
# r one, ten times thy self were happier t
#
#  times thy self were happier than thou a
#
#  self were happier than thou art, if ten
#
#  happier than thou art, if ten of thine
#
# han thou art, if ten of thine ten times
#
# rt, if ten of thine ten times refigured
#
#  of thine ten times refigured thee then
#
# ten times refigured thee then what could
#
# refigured thee then what could death do
#
# thee then what could death do if thou sh
#
# what could death do if thou shouldst dep
#
#  death do if thou shouldst depart, leavi
#
# if thou shouldst depart, leaving thee li
#
# ouldst depart, leaving thee living in po
#
# art, leaving thee living in posterity? b
#
# ng thee living in posterity? be not self
#
# ving in posterity? be not self-willed fo
#
# sterity? be not self-willed for thou art
#
# e not self-willed for thou art much too
#
# -willed for thou art much too fair, to b
#
# r thou art much too fair, to be death's
#
#  much too fair, to be death's conquest a
#
# fair, to be death's conquest and make wo
#
# e death's conquest and make worms thine
#
# conquest and make worms thine heir lo in
#
# nd make worms thine heir lo in the orien
#
# rms thine heir lo in the orient when the
#
# heir lo in the orient when the gracious
#
#  the orient when the gracious light lift
#
# t when the gracious light lifts up his b
#
#  gracious light lifts up his burning hea
#
# light lifts up his burning head, each un
#
# s up his burning head, each under eye do
#
# urning head, each under eye doth homage
#
# d, each under eye doth homage to his new
#
# der eye doth homage to his new-appearing
#
# th homage to his new-appearing sight, se
#
# to his new-appearing sight, serving with
#
# -appearing sight, serving with looks his
#
#  sight, serving with looks his sacred ma
#
# rving with looks his sacred majesty, and
#
#  looks his sacred majesty, and having cl
#
#  sacred majesty, and having climbed the
#
# jesty, and having climbed the steep-up h
#
#  having climbed the steep-up heavenly hi
#
# imbed the steep-up heavenly hill, resemb
#
# steep-up heavenly hill, resembling stron
#
# eavenly hill, resembling strong youth in
#
# ll, resembling strong youth in his middl
#
# ling strong youth in his middle age, yet
#
# g youth in his middle age, yet mortal lo
#
#  his middle age, yet mortal looks adore
#
# e age, yet mortal looks adore his beauty
#
#  mortal looks adore his beauty still, at
#
# oks adore his beauty still, attending on
#
# his beauty still, attending on his golde
#
#  still, attending on his golden pilgrima
#
# tending on his golden pilgrimage but whe
#
#  his golden pilgrimage but when from hig
#
# n pilgrimage but when from highmost pitc
#
# ge but when from highmost pitch with wea
#
# n from highmost pitch with weary car, li
#
# hmost pitch with weary car, like feeble
#
# h with weary car, like feeble age he ree
#
# ry car, like feeble age he reeleth from
#
# ke feeble age he reeleth from the day, t
#
# age he reeleth from the day, the eyes fo
#
# leth from the day, the eyes fore duteous
#
# the day, the eyes fore duteous now conve
#
# he eyes fore duteous now converted are f
#
# re duteous now converted are from his lo
#
#  now converted are from his low tract an
#
# rted are from his low tract and look ano
#
# rom his low tract and look another way s
#
# w tract and look another way so thou, th
#
# d look another way so thou, thy self out
#
# ther way so thou, thy self out-going in
#
# o thou, thy self out-going in thy noon u
#
# y self out-going in thy noon unlooked on
#
# -going in thy noon unlooked on diest unl
#
# thy noon unlooked on diest unless thou g
#
# nlooked on diest unless thou get a son m
#
#  diest unless thou get a son music to he
#
# ess thou get a son music to hear, why he
#
# et a son music to hear, why hear'st thou
#
# usic to hear, why hear'st thou music sad
#
# ar, why hear'st thou music sadly? sweets
#
# ar'st thou music sadly? sweets with swee
#
#  music sadly? sweets with sweets war not
#
# ly? sweets with sweets war not, joy deli
#
#  with sweets war not, joy delights in jo
#
# ts war not, joy delights in joy why lov'
#
# , joy delights in joy why lov'st thou th
#
# ghts in joy why lov'st thou that which t
#
# y why lov'st thou that which thou receiv
#
# st thou that which thou receiv'st not gl
#
# at which thou receiv'st not gladly, or e
#
# hou receiv'st not gladly, or else receiv
#
# 'st not gladly, or else receiv'st with p
#
# adly, or else receiv'st with pleasure th
#
# lse receiv'st with pleasure thine annoy?
#
# 'st with pleasure thine annoy? if the tr
#
# leasure thine annoy? if the true concord
#
# ine annoy? if the true concord of well-t
#
#  if the true concord of well-tuned sound
#
# ue concord of well-tuned sounds, by unio
#
#  of well-tuned sounds, by unions married
#
# uned sounds, by unions married do offend
#
# s, by unions married do offend thine ear
#
# ns married do offend thine ear, they do
#
#  do offend thine ear, they do but sweetl
#
#  thine ear, they do but sweetly chide th
#
# , they do but sweetly chide thee, who co
#
# but sweetly chide thee, who confounds in
#
# y chide thee, who confounds in singlenes
#
# ee, who confounds in singleness the part
#
# nfounds in singleness the parts that tho
#
#  singleness the parts that thou shouldst
#
# s the parts that thou shouldst bear mark
#
# s that thou shouldst bear mark how one s
#
# u shouldst bear mark how one string swee
#
#  bear mark how one string sweet husband
#
#  how one string sweet husband to another
#
# tring sweet husband to another, strikes
#
# t husband to another, strikes each in ea
#
# to another, strikes each in each by mutu
#
# , strikes each in each by mutual orderin
#
# each in each by mutual ordering resembli
#
# ch by mutual ordering resembling sire, a
#
# al ordering resembling sire, and child,
#
# g resembling sire, and child, and happy
#
# ng sire, and child, and happy mother, wh
#
# nd child, and happy mother, who all in o
#
# and happy mother, who all in one, one pl
#
# mother, who all in one, one pleasing not
#
# o all in one, one pleasing note do sing
#
# ne, one pleasing note do sing whose spee
#
# easing note do sing whose speechless son
#
# e do sing whose speechless song being ma
# whose speechless song being many, seemin
#
# chless song being many, seeming one, sin
#
# g being many, seeming one, sings this to
#
# ny, seeming one, sings this to thee, 'th
#
# g one, sings this to thee, 'thou single
#
# gs this to thee, 'thou single wilt prove
#
#  thee, 'thou single wilt prove none' is
#
# ou single wilt prove none' is it for fea
#
# wilt prove none' is it for fear to wet a
#
#  none' is it for fear to wet a widow's e
#
# it for fear to wet a widow's eye, that t
#
# r to wet a widow's eye, that thou consum
#
#  widow's eye, that thou consum'st thy se
#
# ye, that thou consum'st thy self in sing
#
# hou consum'st thy self in single life? a
#
# 'st thy self in single life? ah, if thou
#
# lf in single life? ah, if thou issueless
#
# le life? ah, if thou issueless shalt hap
#
# h, if thou issueless shalt hap to die, t
#
#  issueless shalt hap to die, the world w
#
#  shalt hap to die, the world will wail t
#
#  to die, the world will wail thee like a
#
# he world will wail thee like a makeless
#
# ill wail thee like a makeless wife, the
#
# hee like a makeless wife, the world will
#
#  makeless wife, the world will be thy wi
#
# wife, the world will be thy widow and st
#
# world will be thy widow and still weep,
#
#  be thy widow and still weep, that thou
#
# dow and still weep, that thou no form of
#
# ill weep, that thou no form of thee hast
#
# that thou no form of thee hast left behi
#
# no form of thee hast left behind, when e
#
#  thee hast left behind, when every priva
#
#  left behind, when every private widow w
#
# nd, when every private widow well may ke
#
# very private widow well may keep, by chi
#
# te widow well may keep, by children's ey
#
# ell may keep, by children's eyes, her hu
#
# ep, by children's eyes, her husband's sh
#
# ldren's eyes, her husband's shape in min
#
# es, her husband's shape in mind look wha
#
# sband's shape in mind look what an unthr
#
# ape in mind look what an unthrift in the
#
# d look what an unthrift in the world dot
#
# t an unthrift in the world doth spend sh
#
# ift in the world doth spend shifts but h
#
#  world doth spend shifts but his place,
#
# h spend shifts but his place, for still
#
# ifts but his place, for still the world
#
# is place, for still the world enjoys it
#
# for still the world enjoys it but beauty
#
# the world enjoys it but beauty's waste h
#
# enjoys it but beauty's waste hath in the
#
# but beauty's waste hath in the world an
#
# 's waste hath in the world an end, and k
#
# ath in the world an end, and kept unused
#
#  world an end, and kept unused the user
#
# end, and kept unused the user so destroy
#
# ept unused the user so destroys it no lo
#
#  the user so destroys it no love toward
#
# so destroys it no love toward others in
#
# s it no love toward others in that bosom
#
# ve toward others in that bosom sits that
#
# others in that bosom sits that on himsel
#
# that bosom sits that on himself such mur
#
#  sits that on himself such murd'rous sha
#
#  on himself such murd'rous shame commits
#
# f such murd'rous shame commits for shame
#
# d'rous shame commits for shame deny that
#
# me commits for shame deny that thou bear
#
#  for shame deny that thou bear'st love t
#
#  deny that thou bear'st love to any who
#
#  thou bear'st love to any who for thy se
#
# 'st love to any who for thy self art so
#
# o any who for thy self art so unproviden
#
# for thy self art so unprovident grant if
#
# lf art so unprovident grant if thou wilt
#
# unprovident grant if thou wilt, thou art
#
# t grant if thou wilt, thou art beloved o
#
#  thou wilt, thou art beloved of many, bu
#
# , thou art beloved of many, but that tho
#
#  beloved of many, but that thou none lov
#
# f many, but that thou none lov'st is mos
#
# t that thou none lov'st is most evident
#
# u none lov'st is most evident for thou a
#
# 'st is most evident for thou art so poss
#
# t evident for thou art so possessed with
#
# for thou art so possessed with murd'rous
#
# rt so possessed with murd'rous hate, tha
#
# essed with murd'rous hate, that 'gainst
#
#  murd'rous hate, that 'gainst thy self t
#
#  hate, that 'gainst thy self thou stick'
#
# t 'gainst thy self thou stick'st not to
#
# thy self thou stick'st not to conspire,
#
# hou stick'st not to conspire, seeking th
#
# st not to conspire, seeking that beauteo
#
# conspire, seeking that beauteous roof to
#
# seeking that beauteous roof to ruinate w
#
# at beauteous roof to ruinate which to re
#
# us roof to ruinate which to repair shoul
#
#  ruinate which to repair should be thy c
#
# hich to repair should be thy chief desir
#
# pair should be thy chief desire o change
#
# d be thy chief desire o change thy thoug
#
# hief desire o change thy thought, that i
#
# e o change thy thought, that i may chang
#
#  thy thought, that i may change my mind,
#
# ht, that i may change my mind, shall hat
#
#  may change my mind, shall hate be faire
#
# e my mind, shall hate be fairer lodged t
#
#  shall hate be fairer lodged than gentle
#
# e be fairer lodged than gentle love? be
#
# r lodged than gentle love? be as thy pre
#
# han gentle love? be as thy presence is g
#
#  love? be as thy presence is gracious an
#
# as thy presence is gracious and kind, or
#
# sence is gracious and kind, or to thy se
#
# racious and kind, or to thy self at leas
#
# d kind, or to thy self at least kind-hea
#
#  to thy self at least kind-hearted prove
#
# lf at least kind-hearted prove, make the
#
# t kind-hearted prove, make thee another
#
# rted prove, make thee another self for l
#
# , make thee another self for love of me,
#
# e another self for love of me, that beau
#
# self for love of me, that beauty still m
#
# ove of me, that beauty still may live in
#
#  that beauty still may live in thine or
#
# ty still may live in thine or thee as fa
#
# ay live in thine or thee as fast as thou
#
#  thine or thee as fast as thou shalt wan
#
# thee as fast as thou shalt wane so fast
#
# st as thou shalt wane so fast thou grow'
#
#  shalt wane so fast thou grow'st, in one
#
# e so fast thou grow'st, in one of thine,
#
# thou grow'st, in one of thine, from that
#
# st, in one of thine, from that which tho
#
#  of thine, from that which thou departes
#
#  from that which thou departest, and tha
#
#  which thou departest, and that fresh bl
#
# u departest, and that fresh blood which
#
# t, and that fresh blood which youngly th
#
# t fresh blood which youngly thou bestow'
#
# ood which youngly thou bestow'st, thou m
#
# youngly thou bestow'st, thou mayst call
#
# ou bestow'st, thou mayst call thine, whe
#
# st, thou mayst call thine, when thou fro
#
# ayst call thine, when thou from youth co
#
# thine, when thou from youth convertest,
#
# n thou from youth convertest, herein liv
#
# m youth convertest, herein lives wisdom,
#
# nvertest, herein lives wisdom, beauty, a
#
# herein lives wisdom, beauty, and increas
#
# es wisdom, beauty, and increase, without
#
#  beauty, and increase, without this foll
#
# nd increase, without this folly, age, an
#
# e, without this folly, age, and cold dec
#
#  this folly, age, and cold decay, if all
#
# y, age, and cold decay, if all were mind
#
# d cold decay, if all were minded so, the
#
# ay, if all were minded so, the times sho
#
#  were minded so, the times should cease,
#
# ed so, the times should cease, and three
#
#  times should cease, and threescore year
#
# uld cease, and threescore year would mak
#
#  and threescore year would make the worl
#
# score year would make the world away let
#
#  would make the world away let those who
#
# e the world away let those whom nature h
#
# d away let those whom nature hath not ma
#
#  those whom nature hath not made for sto
#
# m nature hath not made for store, harsh,
#
# ath not made for store, harsh, featurele
#
# de for store, harsh, featureless, and ru
#
# re, harsh, featureless, and rude, barren
#
#  featureless, and rude, barrenly perish
#
# ss, and rude, barrenly perish look whom
#
# de, barrenly perish look whom she best e
#
# ly perish look whom she best endowed, sh
#
# look whom she best endowed, she gave the
#
# she best endowed, she gave thee more whi
#
# ndowed, she gave thee more which bounteo
#
# e gave thee more which bounteous gift th
#
# e more which bounteous gift thou shoulds
#
# ch bounteous gift thou shouldst in bount
#
# us gift thou shouldst in bounty cherish
#
# ou shouldst in bounty cherish she carved
#
# t in bounty cherish she carved thee for
#
# y cherish she carved thee for her seal,
#
# she carved thee for her seal, and meant
#
#  thee for her seal, and meant thereby, t
#
# her seal, and meant thereby, thou should
#
# and meant thereby, thou shouldst print m
#
# thereby, thou shouldst print more, not l
#
# hou shouldst print more, not let that co
#
# st print more, not let that copy die whe
#
# ore, not let that copy die when i do cou
#
# et that copy die when i do count the clo
#
# py die when i do count the clock that te
#
# n i do count the clock that tells the ti
#
# nt the clock that tells the time, and se
#
# ck that tells the time, and see the brav
#
# lls the time, and see the brave day sunk
#
# me, and see the brave day sunk in hideou
#
# e the brave day sunk in hideous night, w
#
# e day sunk in hideous night, when i beho
#
#  in hideous night, when i behold the vio
#
# s night, when i behold the violet past p
#
# hen i behold the violet past prime, and
#
# ld the violet past prime, and sable curl
#
# let past prime, and sable curls all silv
#
# rime, and sable curls all silvered o'er
#
# sable curls all silvered o'er with white
#
# s all silvered o'er with white when loft
#
# ered o'er with white when lofty trees i
#
# with white when lofty trees i see barren
#
#  when lofty trees i see barren of leaves
#
# y trees i see barren of leaves, which er
#
# see barren of leaves, which erst from he
#
#  of leaves, which erst from heat did can
#
# , which erst from heat did canopy the he
#
# st from heat did canopy the herd and sum
#
# at did canopy the herd and summer's gree
#
# opy the herd and summer's green all gird
#
# rd and summer's green all girded up in s
#
# mer's green all girded up in sheaves bor
#
# n all girded up in sheaves borne on the
#
# ed up in sheaves borne on the bier with
#
# heaves borne on the bier with white and
#
# ne on the bier with white and bristly be
#
# bier with white and bristly beard then o
#
# white and bristly beard then of thy beau
#
# bristly beard then of thy beauty do i qu
#
# ard then of thy beauty do i question mak
#
# f thy beauty do i question make that tho
#
# ty do i question make that thou among th
#
# estion make that thou among the wastes o
#
# e that thou among the wastes of time mus
#
# u among the wastes of time must go, sinc
#
# e wastes of time must go, since sweets a
#
# f time must go, since sweets and beautie
#
# t go, since sweets and beauties do thems
#
# e sweets and beauties do themselves fors
#
# nd beauties do themselves forsake, and d
#
# s do themselves forsake, and die as fast
#
# elves forsake, and die as fast as they s
#
# ake, and die as fast as they see others
#
# ie as fast as they see others grow, and
#
#  as they see others grow, and nothing 'g
#
# ee others grow, and nothing 'gainst time
#
# grow, and nothing 'gainst time's scythe
#
# nothing 'gainst time's scythe can make d
#
# ainst time's scythe can make defence sav
#
# 's scythe can make defence save breed to
#
# can make defence save breed to brave him
# efence save breed to brave him, when he
#
# e breed to brave him, when he takes thee
#
#  brave him, when he takes thee hence o t
#
# , when he takes thee hence o that you we
#
# takes thee hence o that you were your se
#
#  hence o that you were your self, but lo
#
# hat you were your self, but love you are
#
# re your self, but love you are no longer
#
# lf, but love you are no longer yours, th
#
# ve you are no longer yours, than you you
#
#  no longer yours, than you your self her
#
#  yours, than you your self here live, ag
#
# an you your self here live, against this
#
# r self here live, against this coming en
#
# e live, against this coming end you shou
#
# ainst this coming end you should prepare
#
#  coming end you should prepare, and your
#
# d you should prepare, and your sweet sem
#
# ld prepare, and your sweet semblance to
#
# , and your sweet semblance to some other
#
#  sweet semblance to some other give so s
#
# blance to some other give so should that
#
# some other give so should that beauty wh
#
#  give so should that beauty which you ho
#
# hould that beauty which you hold in leas
#
#  beauty which you hold in lease find no
#
# ich you hold in lease find no determinat
#
# ld in lease find no determination, then
#
# e find no determination, then you were y
#
# determination, then you were your self a
#
# ion, then you were your self again after
#
# you were your self again after your self
#
# our self again after your self's decease
#
# gain after your self's decease, when you
#
#  your self's decease, when your sweet is
#
# 's decease, when your sweet issue your s
#
# , when your sweet issue your sweet form
#
# r sweet issue your sweet form should bea
#
# sue your sweet form should bear who lets
#
# weet form should bear who lets so fair a
#
# should bear who lets so fair a house fal
#
# r who lets so fair a house fall to decay
#
#  so fair a house fall to decay, which hu
#
#  house fall to decay, which husbandry in
#
# l to decay, which husbandry in honour mi
#
# , which husbandry in honour might uphold
#
# sbandry in honour might uphold, against
#
#  honour might uphold, against the stormy
#
# ght uphold, against the stormy gusts of
#
# , against the stormy gusts of winter's d
#
# the stormy gusts of winter's day and bar
#
#  gusts of winter's day and barren rage o
#
# winter's day and barren rage of death's
#
# ay and barren rage of death's eternal co
#
# ren rage of death's eternal cold? o none
#
# f death's eternal cold? o none but unthr
#
# eternal cold? o none but unthrifts, dear
#
# ld? o none but unthrifts, dear my love y
#
#  but unthrifts, dear my love you know, y
#
# ifts, dear my love you know, you had a f
#
#  my love you know, you had a father, let
#
# ou know, you had a father, let your son
#
# ou had a father, let your son say so not
#
# ather, let your son say so not from the
#
#  your son say so not from the stars do i
#
# say so not from the stars do i my judgem
#
#  from the stars do i my judgement pluck,
#
# stars do i my judgement pluck, and yet m
#
#  my judgement pluck, and yet methinks i
#
# ent pluck, and yet methinks i have astro
#
#  and yet methinks i have astronomy, but
#
# ethinks i have astronomy, but not to tel
#
# have astronomy, but not to tell of good,
#
# nomy, but not to tell of good, or evil l
#
# not to tell of good, or evil luck, of pl
#
# l of good, or evil luck, of plagues, of
#
#  or evil luck, of plagues, of dearths, o
#
# uck, of plagues, of dearths, or seasons'
#
# agues, of dearths, or seasons' quality,
#
# dearths, or seasons' quality, nor can i
#
# r seasons' quality, nor can i fortune to
#
#  quality, nor can i fortune to brief min
#
# nor can i fortune to brief minutes tell
#
# fortune to brief minutes tell pointing t
#
#  brief minutes tell pointing to each his
#
# utes tell pointing to each his thunder,
#
# pointing to each his thunder, rain and w
#
# o each his thunder, rain and wind, or sa
#
#  thunder, rain and wind, or say with pri
#
# rain and wind, or say with princes if it
#
# ind, or say with princes if it shall go
#
# y with princes if it shall go well by of
#
# nces if it shall go well by oft predict
#
#  shall go well by oft predict that i in
#
# well by oft predict that i in heaven fin
#
# t predict that i in heaven find but from
#
# that i in heaven find but from thine eye
#
# heaven find but from thine eyes my knowl
#
# d but from thine eyes my knowledge i der
#
#  thine eyes my knowledge i derive, and c
#
# s my knowledge i derive, and constant st
#
# edge i derive, and constant stars in the
#
# ive, and constant stars in them i read s
#
# onstant stars in them i read such art as
#
# ars in them i read such art as truth and
#
# m i read such art as truth and beauty sh
#
# uch art as truth and beauty shall togeth
#
#  truth and beauty shall together thrive
#
#  beauty shall together thrive if from th
#
# all together thrive if from thy self, to
#
# er thrive if from thy self, to store tho
#
# if from thy self, to store thou wouldst
#
# y self, to store thou wouldst convert or
#
#  store thou wouldst convert or else of t
#
# u wouldst convert or else of thee this i
#
# convert or else of thee this i prognosti
#
#  else of thee this i prognosticate, thy
#
# hee this i prognosticate, thy end is tru
#
#  prognosticate, thy end is truth's and b
#
# cate, thy end is truth's and beauty's do
#
# end is truth's and beauty's doom and dat
#
# th's and beauty's doom and date when i c
#
# eauty's doom and date when i consider ev
#
# om and date when i consider every thing
#
# e when i consider every thing that grows
#
# onsider every thing that grows holds in
#
# ery thing that grows holds in perfection
#
# that grows holds in perfection but a lit
#
#  holds in perfection but a little moment
#
# perfection but a little moment that this
#
#  but a little moment that this huge stag
#
# tle moment that this huge stage presente
#
#  that this huge stage presenteth nought
#
#  huge stage presenteth nought but shows
#
# e presenteth nought but shows whereon th
#
# th nought but shows whereon the stars in
#
# but shows whereon the stars in secret in
#
# whereon the stars in secret influence co
#
# e stars in secret influence comment when
#
#  secret influence comment when i perceiv
#
# fluence comment when i perceive that men
#
# mment when i perceive that men as plants
#
#  i perceive that men as plants increase,
#
# e that men as plants increase, cheered a
#
#  as plants increase, cheered and checked
#
#  increase, cheered and checked even by t
#
#  cheered and checked even by the self-sa
#
# nd checked even by the self-same sky vau
#
#  even by the self-same sky vaunt in thei
#
# he self-same sky vaunt in their youthful
#
# me sky vaunt in their youthful sap, at h
#
# nt in their youthful sap, at height decr
#
# r youthful sap, at height decrease, and
#
#  sap, at height decrease, and wear their
#
# eight decrease, and wear their brave sta
#
# ease, and wear their brave state out of
#
# wear their brave state out of memory the
#
#  brave state out of memory then the conc
#
# te out of memory then the conceit of thi
#
# memory then the conceit of this inconsta
#
# n the conceit of this inconstant stay, s
#
# eit of this inconstant stay, sets you mo
#
# s inconstant stay, sets you most rich in
#
# nt stay, sets you most rich in youth bef
#
# ets you most rich in youth before my sig
#
# st rich in youth before my sight, where
#
#  youth before my sight, where wasteful t
#
# ore my sight, where wasteful time debate
#
# ht, where wasteful time debateth with de
#
# wasteful time debateth with decay to cha
#
# ime debateth with decay to change your d
#
# th with decay to change your day of yout
#
# cay to change your day of youth to sulli
#
# nge your day of youth to sullied night,
#
# ay of youth to sullied night, and all in
#
# h to sullied night, and all in war with
#
# ed night, and all in war with time for l
#
# and all in war with time for love of you
#
#  war with time for love of you, as he ta
#
# time for love of you, as he takes from y
#
# ove of you, as he takes from you, i engr
#
# , as he takes from you, i engraft you ne
#
# kes from you, i engraft you new but wher
#
# ou, i engraft you new but wherefore do n
#
# aft you new but wherefore do not you a m
#
# w but wherefore do not you a mightier wa
#
# efore do not you a mightier way make war
#
# ot you a mightier way make war upon this
#
# ightier way make war upon this bloody ty
#
# y make war upon this bloody tyrant time?
#
#  upon this bloody tyrant time? and forti
#
#  bloody tyrant time? and fortify your se
#
# rant time? and fortify your self in your
#
#  and fortify your self in your decay wit
#
# fy your self in your decay with means mo
#
# lf in your decay with means more blessed
#
#  decay with means more blessed than my b
#
# h means more blessed than my barren rhym
#
# re blessed than my barren rhyme? now sta
#
#  than my barren rhyme? now stand you on
#
# arren rhyme? now stand you on the top of
#
# e? now stand you on the top of happy hou
#
# nd you on the top of happy hours, and ma
#
# the top of happy hours, and many maiden
#
#  happy hours, and many maiden gardens ye
#
# rs, and many maiden gardens yet unset, w
#
# ny maiden gardens yet unset, with virtuo
#
# gardens yet unset, with virtuous wish wo
#
# t unset, with virtuous wish would bear y
#
# ith virtuous wish would bear you living
#
# us wish would bear you living flowers, m
#
# uld bear you living flowers, much liker
#
# ou living flowers, much liker than your
#
# flowers, much liker than your painted co
#
# uch liker than your painted counterfeit
#
# than your painted counterfeit so should
#
# painted counterfeit so should the lines
#
# unterfeit so should the lines of life th
#
# so should the lines of life that life re
#
# the lines of life that life repair which
#
# of life that life repair which this time
#
# at life repair which this time's pencil
#
# pair which this time's pencil or my pupi
#
#  this time's pencil or my pupil pen neit
#
# 's pencil or my pupil pen neither in inw
#
# or my pupil pen neither in inward worth
#
# l pen neither in inward worth nor outwar
#
# her in inward worth nor outward fair can
#
# ard worth nor outward fair can make you
#
# nor outward fair can make you live your
#
# d fair can make you live your self in ey
#
#  make you live your self in eyes of men
#
# live your self in eyes of men to give aw
#
# self in eyes of men to give away your se
#
# es of men to give away your self, keeps
#
# to give away your self, keeps your self
#
# ay your self, keeps your self still, and
#
# lf, keeps your self still, and you must
#
# your self still, and you must live drawn
#
# still, and you must live drawn by your o
#
#  you must live drawn by your own sweet s
#
# live drawn by your own sweet skill who w
#
#  by your own sweet skill who will believ
#
# wn sweet skill who will believe my verse
#
# kill who will believe my verse in time t
#
# ill believe my verse in time to come if
#
# e my verse in time to come if it were fi
#
#  in time to come if it were filled with
#
# o come if it were filled with your most
#
# it were filled with your most high deser
#
# lled with your most high deserts? though
#
# your most high deserts? though yet heave
#
# high deserts? though yet heaven knows it
#
# ts? though yet heaven knows it is but as
#
#  yet heaven knows it is but as a tomb wh
#
# n knows it is but as a tomb which hides
#  is but as a tomb which hides your life,
#
#  a tomb which hides your life, and shows
#
# ich hides your life, and shows not half
#
# your life, and shows not half your parts
#
#  and shows not half your parts if i coul
#
#  not half your parts if i could write th
#
# your parts if i could write the beauty o
#
#  if i could write the beauty of your eye
#
# d write the beauty of your eyes, and in
#
# e beauty of your eyes, and in fresh numb
#
# f your eyes, and in fresh numbers number
#
# s, and in fresh numbers number all your
#
# fresh numbers number all your graces, th
#
# ers number all your graces, the age to c
#
#  all your graces, the age to come would
#
# graces, the age to come would say this p
#
# e age to come would say this poet lies,
#
# ome would say this poet lies, such heave
#
# say this poet lies, such heavenly touche
#
# oet lies, such heavenly touches ne'er to
#
# such heavenly touches ne'er touched eart
#
# nly touches ne'er touched earthly faces
#
# s ne'er touched earthly faces so should
#
# uched earthly faces so should my papers
#
# hly faces so should my papers yellowed w
#
# so should my papers yellowed with their
#
# my papers yellowed with their age be sco
#
# yellowed with their age be scorned, like
#
# ith their age be scorned, like old men o
#
# age be scorned, like old men of less tru
#
# rned, like old men of less truth than to
#
#  old men of less truth than tongue, and
#
# f less truth than tongue, and your true
#
# th than tongue, and your true rights be
#
# ngue, and your true rights be termed a p
#
# your true rights be termed a poet's rage
#
# rights be termed a poet's rage, and stre
#
# termed a poet's rage, and stretched metr
#
# oet's rage, and stretched metre of an an
#
# , and stretched metre of an antique song
#
# tched metre of an antique song but were
#
# e of an antique song but were some child
#
# tique song but were some child of yours
#
#  but were some child of yours alive that
#
# some child of yours alive that time, you
#
#  of yours alive that time, you should li
#
# alive that time, you should live twice i
#
#  time, you should live twice in it, and
#
#  should live twice in it, and in my rhym
#
# ve twice in it, and in my rhyme shall i
#
# n it, and in my rhyme shall i compare th
#
# in my rhyme shall i compare thee to a su
#
# e shall i compare thee to a summer's day
#
# compare thee to a summer's day? thou art
#
# ee to a summer's day? thou art more love
#
# mmer's day? thou art more lovely and mor
#
# ? thou art more lovely and more temperat
#
#  more lovely and more temperate rough wi
#
# ly and more temperate rough winds do sha
#
# e temperate rough winds do shake the dar
#
# e rough winds do shake the darling buds
#
# nds do shake the darling buds of may, an
#
# ke the darling buds of may, and summer's
#
# ling buds of may, and summer's lease hat
#
# of may, and summer's lease hath all too
#
# d summer's lease hath all too short a da
#
#  lease hath all too short a date sometim
#
# h all too short a date sometime too hot
#
# short a date sometime too hot the eye of
#
# te sometime too hot the eye of heaven sh
#
# e too hot the eye of heaven shines, and
#
# the eye of heaven shines, and often is h
#
#  heaven shines, and often is his gold co
#
# ines, and often is his gold complexion d
#
# often is his gold complexion dimmed, and
#
# is gold complexion dimmed, and every fai
#
# mplexion dimmed, and every fair from fai
#
# immed, and every fair from fair sometime
#
#  every fair from fair sometime declines,
#
# r from fair sometime declines, by chance
#
# r sometime declines, by chance, or natur
#
#  declines, by chance, or nature's changi
#
#  by chance, or nature's changing course
#
# , or nature's changing course untrimmed
#
# e's changing course untrimmed but thy et
#
# ng course untrimmed but thy eternal summ
#
# untrimmed but thy eternal summer shall n
#
# but thy eternal summer shall not fade, n
#
# ernal summer shall not fade, nor lose po
#
# er shall not fade, nor lose possession o
#
# ot fade, nor lose possession of that fai
#
# or lose possession of that fair thou ow'
#
# ssession of that fair thou ow'st, nor sh
#
# f that fair thou ow'st, nor shall death
#
# r thou ow'st, nor shall death brag thou
#
# st, nor shall death brag thou wand'rest
#
# all death brag thou wand'rest in his sha
#
# brag thou wand'rest in his shade, when i
#
# wand'rest in his shade, when in eternal
#
# in his shade, when in eternal lines to t
#
# de, when in eternal lines to time thou g
#
# n eternal lines to time thou grow'st, so
#
# lines to time thou grow'st, so long as m
#
# ime thou grow'st, so long as men can bre
#
# row'st, so long as men can breathe or ey
#
#  long as men can breathe or eyes can see
#
# en can breathe or eyes can see, so long
#
# athe or eyes can see, so long lives this
#
# es can see, so long lives this, and this
#
# , so long lives this, and this gives lif
#
# lives this, and this gives life to thee
#
# , and this gives life to thee devouring
#
#  gives life to thee devouring time blunt
#
# e to thee devouring time blunt thou the
#
# devouring time blunt thou the lion's paw
#
# time blunt thou the lion's paws, and mak
#
#  thou the lion's paws, and make the eart
#
# lion's paws, and make the earth devour h
#
# s, and make the earth devour her own swe
#
# e the earth devour her own sweet brood,
#
# h devour her own sweet brood, pluck the
#
# er own sweet brood, pluck the keen teeth
#
# et brood, pluck the keen teeth from the
#
# pluck the keen teeth from the fierce tig
#
# keen teeth from the fierce tiger's jaws,
#
#  from the fierce tiger's jaws, and burn
#
# fierce tiger's jaws, and burn the long-l
#
# er's jaws, and burn the long-lived phoen
#
#  and burn the long-lived phoenix, in her
#
# the long-lived phoenix, in her blood, ma
#
# ived phoenix, in her blood, make glad an
#
# ix, in her blood, make glad and sorry se
#
#  blood, make glad and sorry seasons as t
#
# ke glad and sorry seasons as thou fleet'
#
# d sorry seasons as thou fleet'st, and do
#
# asons as thou fleet'st, and do whate'er
#
# hou fleet'st, and do whate'er thou wilt
#
# st, and do whate'er thou wilt swift-foot
#
#  whate'er thou wilt swift-footed time to
#
# thou wilt swift-footed time to the wide
#
# swift-footed time to the wide world and
#
# ed time to the wide world and all her fa
#
#  the wide world and all her fading sweet
#
# world and all her fading sweets but i fo
#
# all her fading sweets but i forbid thee
#
# ding sweets but i forbid thee one most h
#
# s but i forbid thee one most heinous cri
#
# rbid thee one most heinous crime, o carv
#
# one most heinous crime, o carve not with
#
# einous crime, o carve not with thy hours
#
# me, o carve not with thy hours my love's
#
# e not with thy hours my love's fair brow
#
#  thy hours my love's fair brow, nor draw
#
#  my love's fair brow, nor draw no lines
#
#  fair brow, nor draw no lines there with
#
# , nor draw no lines there with thine ant
# ...
#
# ve's eye be true, that is so vexed with
#
# e true, that is so vexed with watching a
#
# at is so vexed with watching and with te
#
# exed with watching and with tears? no ma
#
# watching and with tears? no marvel then
#
# nd with tears? no marvel then though i m
#
# ars? no marvel then though i mistake my
#
# rvel then though i mistake my view, the
#
# though i mistake my view, the sun it sel
#
# istake my view, the sun it self sees not
#
# view, the sun it self sees not, till hea
#
# sun it self sees not, till heaven clears
#
# f sees not, till heaven clears o cunning
#
# , till heaven clears o cunning love, wit
#
# ven clears o cunning love, with tears th
#
#  o cunning love, with tears thou keep'st
#
#  love, with tears thou keep'st me blind,
#
# h tears thou keep'st me blind, lest eyes
#
# ou keep'st me blind, lest eyes well-seei
#  me blind, lest eyes well-seeing thy fou
#
#  lest eyes well-seeing thy foul faults s
#
#  well-seeing thy foul faults should find
#
# ng thy foul faults should find canst tho
#
# l faults should find canst thou o cruel,
#
# hould find canst thou o cruel, say i lov
#
#  canst thou o cruel, say i love thee not
#
# u o cruel, say i love thee not, when i a
#
#  say i love thee not, when i against my
#
# e thee not, when i against my self with
#
# , when i against my self with thee parta
#
# gainst my self with thee partake? do i n
#
# self with thee partake? do i not think o
#
# thee partake? do i not think on thee whe
#
# ke? do i not think on thee when i forgot
#
# ot think on thee when i forgot am of my
#
# n thee when i forgot am of my self, all-
#
# n i forgot am of my self, all-tyrant, fo
#
#  am of my self, all-tyrant, for thy sake
#
# self, all-tyrant, for thy sake? who hate
#
# tyrant, for thy sake? who hateth thee th
#
# r thy sake? who hateth thee that i do ca
#
# ? who hateth thee that i do call my frie
#
# th thee that i do call my friend, on who
#
# at i do call my friend, on whom frown'st
#
# ll my friend, on whom frown'st thou that
#
# nd, on whom frown'st thou that i do fawn
#
# m frown'st thou that i do fawn upon, nay
#
#  thou that i do fawn upon, nay if thou l
#
#  i do fawn upon, nay if thou lour'st on
#
#  upon, nay if thou lour'st on me do i no
#
#  if thou lour'st on me do i not spend re
#
# our'st on me do i not spend revenge upon
#
# me do i not spend revenge upon my self w
#
# t spend revenge upon my self with presen
#
# venge upon my self with present moan? wh
#
#  my self with present moan? what merit d
#
# ith present moan? what merit do i in my
#
# t moan? what merit do i in my self respe
#
# at merit do i in my self respect, that i
#
# o i in my self respect, that is so proud
#
# self respect, that is so proud thy servi
#
# ct, that is so proud thy service to desp
#
# s so proud thy service to despise, when
#
#  thy service to despise, when all my bes
#
# ce to despise, when all my best doth wor
#
# ise, when all my best doth worship thy d
#
# all my best doth worship thy defect, com
#
# t doth worship thy defect, commanded by
#
# ship thy defect, commanded by the motion
#
# efect, commanded by the motion of thine
#
# manded by the motion of thine eyes? but
#
# the motion of thine eyes? but love hate
#
#  of thine eyes? but love hate on for now
#
# eyes? but love hate on for now i know th
#
# love hate on for now i know thy mind, th
#
# on for now i know thy mind, those that c
#
#  i know thy mind, those that can see tho
#
# y mind, those that can see thou lov'st,
#
# ose that can see thou lov'st, and i am b
#
# an see thou lov'st, and i am blind o fro
#
# u lov'st, and i am blind o from what pow
#
# and i am blind o from what power hast th
#
# lind o from what power hast thou this po
#
# m what power hast thou this powerful mig
#
# er hast thou this powerful might, with i
#
# ou this powerful might, with insufficien
#
# werful might, with insufficiency my hear
#
# ht, with insufficiency my heart to sway,
#
# nsufficiency my heart to sway, to make m
#
# cy my heart to sway, to make me give the
#
# t to sway, to make me give the lie to my
#
#  to make me give the lie to my true sigh
#
# e give the lie to my true sight, and swe
#
#  lie to my true sight, and swear that br
#
#  true sight, and swear that brightness d
#
# t, and swear that brightness doth not gr
#
# ar that brightness doth not grace the da
#
# ightness doth not grace the day? whence
#
# oth not grace the day? whence hast thou
#
# ace the day? whence hast thou this becom
#
# y? whence hast thou this becoming of thi
#
# hast thou this becoming of things ill, t
#
# this becoming of things ill, that in the
#
# ing of things ill, that in the very refu
#
# ngs ill, that in the very refuse of thy
#
# hat in the very refuse of thy deeds, the
#
#  very refuse of thy deeds, there is such
#
# se of thy deeds, there is such strength
#
# deeds, there is such strength and warran
#
# re is such strength and warrantise of sk
#
#  strength and warrantise of skill, that
#
# and warrantise of skill, that in my mind
#
# tise of skill, that in my mind thy worst
#
# ill, that in my mind thy worst all best
#
# in my mind thy worst all best exceeds? w
#
#  thy worst all best exceeds? who taught
#
#  all best exceeds? who taught thee how t
#
# exceeds? who taught thee how to make me
#
# ho taught thee how to make me love thee
#
# thee how to make me love thee more, the
#
# o make me love thee more, the more i hea
#
# love thee more, the more i hear and see
#
# more, the more i hear and see just cause
#
# more i hear and see just cause of hate?
#
# r and see just cause of hate? o though i
#
# just cause of hate? o though i love what
#
#  of hate? o though i love what others do
#
# o though i love what others do abhor, wi
#
#  love what others do abhor, with others
#
#  others do abhor, with others thou shoul
#
#  abhor, with others thou shouldst not ab
#
# th others thou shouldst not abhor my sta
#
# thou shouldst not abhor my state if thy
#
# dst not abhor my state if thy unworthine
#
# hor my state if thy unworthiness raised
#
# te if thy unworthiness raised love in me
#
# unworthiness raised love in me, more wor
#
# ss raised love in me, more worthy i to b
#
# love in me, more worthy i to be beloved
#
# , more worthy i to be beloved of thee lo
#
# thy i to be beloved of thee love is too
#
# e beloved of thee love is too young to k
#
# of thee love is too young to know what c
#
# ve is too young to know what conscience
#
# young to know what conscience is, yet wh
#
# now what conscience is, yet who knows no
#
# onscience is, yet who knows not conscien
#
# is, yet who knows not conscience is born
#
# o knows not conscience is born of love?
#
# t conscience is born of love? then gentl
#
# ce is born of love? then gentle cheater
#
#  of love? then gentle cheater urge not m
#
# then gentle cheater urge not my amiss, l
#
# e cheater urge not my amiss, lest guilty
#
# urge not my amiss, lest guilty of my fau
#
# y amiss, lest guilty of my faults thy sw
#
# est guilty of my faults thy sweet self p
#
#  of my faults thy sweet self prove for t
#
# lts thy sweet self prove for thou betray
#
# eet self prove for thou betraying me, i
#
# rove for thou betraying me, i do betray
#
# hou betraying me, i do betray my nobler
#
# ing me, i do betray my nobler part to my
#
# do betray my nobler part to my gross bod
#
# my nobler part to my gross body's treaso
#
# part to my gross body's treason, my soul
#
#  gross body's treason, my soul doth tell
#
# y's treason, my soul doth tell my body t
#
# n, my soul doth tell my body that he may
#
#  doth tell my body that he may, triumph
#
#  my body that he may, triumph in love, f
#
# hat he may, triumph in love, flesh stays
#
# , triumph in love, flesh stays no farthe
#
# in love, flesh stays no farther reason,
#
# lesh stays no farther reason, but rising
#
#  no farther reason, but rising at thy na
#
# r reason, but rising at thy name doth po
#
# but rising at thy name doth point out th
#
#  at thy name doth point out thee, as his
#
# me doth point out thee, as his triumphan
#
# int out thee, as his triumphant prize, p
#
# ee, as his triumphant prize, proud of th
#
#  triumphant prize, proud of this pride,
#
# t prize, proud of this pride, he is cont
#
# roud of this pride, he is contented thy
#
# is pride, he is contented thy poor drudg
#
# he is contented thy poor drudge to be, t
#
# ented thy poor drudge to be, to stand in
#
# poor drudge to be, to stand in thy affai
#
# e to be, to stand in thy affairs, fall b
#
# o stand in thy affairs, fall by thy side
#
#  thy affairs, fall by thy side no want o
#
# rs, fall by thy side no want of conscien
#
# y thy side no want of conscience hold it
#
#  no want of conscience hold it that i ca
#
# f conscience hold it that i call, her lo
#
# ce hold it that i call, her love, for wh
#
#  that i call, her love, for whose dear l
#
# ll, her love, for whose dear love i rise
#
# ve, for whose dear love i rise and fall
#
# ose dear love i rise and fall in loving
#
# ove i rise and fall in loving thee thou
#
#  and fall in loving thee thou know'st i
#
# in loving thee thou know'st i am forswor
#
# thee thou know'st i am forsworn, but tho
#
# know'st i am forsworn, but thou art twic
#
# am forsworn, but thou art twice forsworn
#
# n, but thou art twice forsworn to me lov
#
# u art twice forsworn to me love swearing
#
# e forsworn to me love swearing, in act t
#
#  to me love swearing, in act thy bed-vow
#
# e swearing, in act thy bed-vow broke and
#
# , in act thy bed-vow broke and new faith
#
# hy bed-vow broke and new faith torn, in
#
#  broke and new faith torn, in vowing new
#
#  new faith torn, in vowing new hate afte
#
#  torn, in vowing new hate after new love
#
# vowing new hate after new love bearing b
#
#  hate after new love bearing but why of
#
# r new love bearing but why of two oaths'
#
#  bearing but why of two oaths' breach do
#
# ut why of two oaths' breach do i accuse
#
# two oaths' breach do i accuse thee, when
#
#  breach do i accuse thee, when i break t
#
#  i accuse thee, when i break twenty? i a
#
# thee, when i break twenty? i am perjured
#
#  i break twenty? i am perjured most, for
#
# wenty? i am perjured most, for all my vo
#
# m perjured most, for all my vows are oat
#
#  most, for all my vows are oaths but to
#
#  all my vows are oaths but to misuse the
#
# ws are oaths but to misuse thee and all
#
# hs but to misuse thee and all my honest
#
# misuse thee and all my honest faith in t
#
# e and all my honest faith in thee is los
#
# my honest faith in thee is lost for i ha
#
# faith in thee is lost for i have sworn d
#
# hee is lost for i have sworn deep oaths
#
# t for i have sworn deep oaths of thy dee
#
# ve sworn deep oaths of thy deep kindness
#
# eep oaths of thy deep kindness oaths of
#
# of thy deep kindness oaths of thy love,
#
# p kindness oaths of thy love, thy truth,
#
#  oaths of thy love, thy truth, thy const
#
# thy love, thy truth, thy constancy, and
#
# thy truth, thy constancy, and to enlight
#
#  thy constancy, and to enlighten thee ga
#
# ancy, and to enlighten thee gave eyes to
#
# to enlighten thee gave eyes to blindness
#
# en thee gave eyes to blindness, or made
#
# ve eyes to blindness, or made them swear
#
#  blindness, or made them swear against t
#
# , or made them swear against the thing t
#
# them swear against the thing they see fo
#
#  against the thing they see for i have s
#
# he thing they see for i have sworn thee
#
# hey see for i have sworn thee fair more
#
# r i have sworn thee fair more perjured i
#
# worn thee fair more perjured i, to swear
#
# fair more perjured i, to swear against t
#
# perjured i, to swear against the truth s
#
# , to swear against the truth so foul a b
#
#  against the truth so foul a be cupid la
#
# he truth so foul a be cupid laid by his
#
# o foul a be cupid laid by his brand and
#
# e cupid laid by his brand and fell aslee
#
# id by his brand and fell asleep, a maid
#
# brand and fell asleep, a maid of dian's
#
# fell asleep, a maid of dian's this advan
#
# p, a maid of dian's this advantage found
#
# of dian's this advantage found, and his
#
# this advantage found, and his love-kindl
#
# tage found, and his love-kindling fire d
#
# , and his love-kindling fire did quickly
#
# love-kindling fire did quickly steep in
#
# ing fire did quickly steep in a cold val
#
# id quickly steep in a cold valley-founta
#
#  steep in a cold valley-fountain of that
#
# a cold valley-fountain of that ground wh
#
# ley-fountain of that ground which borrow
#
# in of that ground which borrowed from th
#
#  ground which borrowed from this holy fi
#
# ich borrowed from this holy fire of love
#
# ed from this holy fire of love, a datele
#
# is holy fire of love, a dateless lively
#
# re of love, a dateless lively heat still
#
# , a dateless lively heat still to endure
#
# ss lively heat still to endure, and grew
#
# heat still to endure, and grew a seeting
#
#  to endure, and grew a seeting bath whic
#
# , and grew a seeting bath which yet men
#
#  a seeting bath which yet men prove, aga
#  bath which yet men prove, against stran
#
# h yet men prove, against strange maladie
#
# prove, against strange maladies a sovere
#
# inst strange maladies a sovereign cure b
#
# ge maladies a sovereign cure but at my m
#
# s a sovereign cure but at my mistress' e
#
# ign cure but at my mistress' eye love's
#
# ut at my mistress' eye love's brand new-
#
# istress' eye love's brand new-fired, the
#
# ye love's brand new-fired, the boy for t
#
# brand new-fired, the boy for trial needs
#
# fired, the boy for trial needs would tou
#
#  boy for trial needs would touch my brea
#
# rial needs would touch my breast, i sick
#
#  would touch my breast, i sick withal th
#
# ch my breast, i sick withal the help of
#
# st, i sick withal the help of bath desir
#
#  withal the help of bath desired, and th
#
# e help of bath desired, and thither hied
#
# bath desired, and thither hied a sad dis
#
# ed, and thither hied a sad distempered g
#
# ither hied a sad distempered guest but f
#
#  a sad distempered guest but found no cu
#
# tempered guest but found no cure, the ba
#
# uest but found no cure, the bath for my
#
# ound no cure, the bath for my help lies,
#
# re, the bath for my help lies, where cup
#
# th for my help lies, where cupid got new
#
# help lies, where cupid got new fire my m
#
#  where cupid got new fire my mistress' e
#
# id got new fire my mistress' eyes the li
#
#  fire my mistress' eyes the little love-
#
# istress' eyes the little love-god lying
#
# yes the little love-god lying once aslee
#
# ttle love-god lying once asleep, laid by
#
# god lying once asleep, laid by his side
#
# once asleep, laid by his side his heart-
#
# p, laid by his side his heart-inflaming
#
#  his side his heart-inflaming brand, whi
#
# his heart-inflaming brand, whilst many n
#
# inflaming brand, whilst many nymphs that
#
# brand, whilst many nymphs that vowed cha
#
# lst many nymphs that vowed chaste life t
#
# ymphs that vowed chaste life to keep, ca
#
#  vowed chaste life to keep, came trippin
#
# ste life to keep, came tripping by, but
#
# o keep, came tripping by, but in her mai
#
# me tripping by, but in her maiden hand,
#
# g by, but in her maiden hand, the faires
#
# in her maiden hand, the fairest votary t
#
# den hand, the fairest votary took up tha
#
# the fairest votary took up that fire, wh
#
# t votary took up that fire, which many l
#
# ook up that fire, which many legions of
#
# t fire, which many legions of true heart
#
# ich many legions of true hearts had warm
#
# egions of true hearts had warmed, and so
#
# true hearts had warmed, and so the gener
#
# s had warmed, and so the general of hot
#
# ed, and so the general of hot desire, wa
#
#  the general of hot desire, was sleeping
#
# al of hot desire, was sleeping by a virg
#
# desire, was sleeping by a virgin hand di
#
# s sleeping by a virgin hand disarmed thi
#
#  by a virgin hand disarmed this brand sh
#
# in hand disarmed this brand she quenched
#
# sarmed this brand she quenched in a cool
#
# s brand she quenched in a cool well by,
#
# e quenched in a cool well by, which from
#
#  in a cool well by, which from love's fi
#
#  well by, which from love's fire took he
#
# which from love's fire took heat perpetu
#
#  love's fire took heat perpetual, growin
#
# re took heat perpetual, growing a bath a
#
# at perpetual, growing a bath and healthf
#
# al, growing a bath and healthful remedy,
#
# g a bath and healthful remedy, for men d
#
# nd healthful remedy, for men discased, b
#
# ul remedy, for men discased, but i my mi
#
#  for men discased, but i my mistress' th
#
# iscased, but i my mistress' thrall, came
#
# ut i my mistress' thrall, came there for
#
# stress' thrall, came there for cure and
#
# rall, came there for cure and this by th
#
#  there for cure and this by that i prove
#
#  cure and this by that i prove, love's f
#
# this by that i prove, love's fire heats
#
# at i prove, love's fire heats water, wat
#
# , love's fire heats water, water cools n

# %% [markdown]
# # Rhyme, Limerick, Haiku

# %% [markdown]
# # Rhyme

# %% [markdown]
# # For Generating Rhymes

# %%
def generate_emission1(self, M, seed):
        '''
        Generates an emission of length M, assuming that the starting state
        is chosen uniformly at random. 

        Arguments:
            M:          Length of the emission to generate.

        Returns:
            emission:   The randomly generated emission as a list.

            states:     The randomly generated states as a list.
        '''
        
        #O: The (i, j)^th element is the probability of
        # emitting observation j given state i.
        O = np.array(self.O)
        emission = []
        emission.append(seed)
       
        # generate first state given this emission 
        col_states = O[:, seed]
       
        # Choose the state having the highest probability of generating
        # this emission. 
        
        state = np.argmax(col_states)
        #state = col_states.argsort()[-1:][::-1]
    
        #col_sum = sum(col_states)
        # normalize the probabilities 
        #col_states *= (1.0 / col_sum)
       # if len(col_states) == 1:
          #  col_states = [1]
        #state = np.random.choice(len(col_states), p=col_states)
        
        
        states = []
        for t in range(M-1):
            # Append state.
            states.append(state)

            # Sample next observation.
            rand_var = random.uniform(0, 1)
            next_obs = 0

            while rand_var > 0:
                rand_var -= self.O[state][next_obs]
                next_obs += 1

            next_obs -= 1
            emission.append(next_obs)
            #emission.insert(0, next_obs)

            # Sample next state.
            rand_var = random.uniform(0, 1)
            next_state = 0

            while rand_var > 0:
                rand_var -= self.A[state][next_state]
                next_state += 1

            next_state -= 1
            state = next_state
            
        emission = emission[::-1] # reverse emissions
        return emission, states
    
    
def obs_map_reverser1(obs_map):
    obs_map_r = {}

    for key in obs_map:
        obs_map_r[obs_map[key]] = key

    return obs_map_r

def sample_sentence1(hmm, obs_map, seed, n_words=100):
    # Get reverse map.
    seed_idx = obs_map[seed]
    obs_map_r = obs_map_reverser1(obs_map)

    # obs_map is of the form key=word: val=identifier
    # Pass the identifier 

    
    # Sample and convert sentence.
    emission, states = generate_emission1(hmm, n_words, seed_idx)
    sentence = [obs_map_r[i] for i in emission]

    return ' '.join(sentence).capitalize() + '...'

# %%
def parse_observations_reverse(text):
    # Convert text to dataset.
    lines = [line.split() for line in text.split('\n') if line.split()]

    obs_counter = 0
    obs = []
    obs_map = {}

    for line in reversed(lines):
        obs_elem = []
        
        for word in reversed(line):
            word = re.sub(r'[^a-zA-Z\-\']', '', word).lower()
            #word = re.sub(r'[^\w\-\']', '', word).lower() 
            
            #word = re.sub(r'[^\w]', '', word).lower()
            if word not in obs_map:
                # Add unique words to the observations map.
                obs_map[word] = obs_counter
                obs_counter += 1
            
            # Add the encoded word.
            obs_elem.append(obs_map[word])
        
        # Add the encoded sequence.
        obs.append(obs_elem)

    return obs, obs_map

# %%
# Rhyming

    #O: Observation matrix with dimensions L x D.
    #The (i, j)^th element is the probability of
    #emitting observation j given state i.
            
rhyming_pairs = [("cruel", "fuel"), ("old", "cold"), ("prime", "time"), \
                ("meet", "sweet"), ("hence", "defence"), ("prognosticate", "date"), \
                ("womb", "tomb"), ("use", "abuse"), ("spend", "lend"), ("art", "depart"), \
                ("fair", "heir"), ("light", "sight"), ("hill", "still"), ("age", "pilgrimage"), \
                ("sounds", "confounds"), ("one", "none"), ("mother", "another"), \
                 ("weep", "keep"), ("fade", "shade"), ("conspire", "desire"), ("mind", "kind"), \
                ("night", "sight"), ("rhyme", "time"), ("dimmed", "untrimmed"), ("life", "wife"), \
                ("cherish", "perish"), ("make", "forsake"), ("give", "live"), ("decay", "day"), \
                 ("pluck", "luck"), ("shines", "declines")]

# First remember to train on reversed text 
text = open(os.path.join(os.getcwd(), 'data_Shakespeare/shakespeare.txt')).read()
obs, obs_map = parse_observations_reverse(text)

# %%
# Training HMM with 4 states on reversed text 
hmm4 = unsupervised_HMM(obs, 4, 100)
# Out:
# Iteration: 10
# Iteration: 20
# Iteration: 30
# Iteration: 40
# Iteration: 50
# Iteration: 60
# Iteration: 70
# Iteration: 80
# Iteration: 90
# Iteration: 100

# %%
rhyming_sonnet = random.sample(rhyming_pairs, 14)

r1 = rhyming_sonnet[:7]
r2 = rhyming_sonnet[7:]

for i in range(3):
    a1, a2 = r1[i]
    b1, b2 = r2[i]
    print(sample_sentence1(hmm4, obs_map, a1, n_words=8))
    print(sample_sentence1(hmm4, obs_map, b1, n_words=8))
    print(sample_sentence1(hmm4, obs_map, a2, n_words=8))
    print(sample_sentence1(hmm4, obs_map, b2, n_words=8))


# printing final line of english sonnet 
a1, a2 = r1[4]
print("  " + str(sample_sentence1(hmm4, obs_map, a1, n_words=8)))
print("  " + str(sample_sentence1(hmm4, obs_map, a2, n_words=8)))
# Out:
# But beast my with there for forbid light...
# Mayst to the page is mine stays cherish...
# Makes thee lord with though my gone sight...
# His travail thy penury yet stop  perish...
# To woo he another give love summer prognosticate...
# Still ah prizing poet's sweet my matter hence...
# Full perjured but winter to on kill date...
# Wretched one steepy for so me sharp defence...
# O thee tongue-tied it plague pen tender one...
# Rhymers in my deeds that more faults shines...
# See not in her may be remains none...
# So of thoughts this for time's view declines...
#   Barrenly in when eye's and their am cruel...
#   Gives aside me once thou such cars fuel...

# %%
# Training HMM with 10 states on reversed text
hmm10 = unsupervised_HMM(obs, 10, 100)
# Out:
# Iteration: 10
# Iteration: 20
# Iteration: 30
# Iteration: 40
# Iteration: 50
# Iteration: 60
# Iteration: 70
# Iteration: 80
# Iteration: 90
# Iteration: 100

# %%
rhyming_sonnet = random.sample(rhyming_pairs, 7)
for (a,b) in rhyming_sonnet:
    print(sample_sentence1(hmm10, obs_map, a, n_words=10))
    print(sample_sentence1(hmm10, obs_map, b, n_words=10))
# Out:
# King with th' shall store and of require  sounds...
# Sluttish vex can hue repair perfection love's will  confounds...
# Th' persuade it book willing brass nor weary  spend...
# With made it can thy abuses brief infection prove lend...
# Perhaps injurious hold the him and my elements young hence...
# Feeble alas is have thee thou a scope argument defence...
# Youthful drudge are a the jewel which your save prognosticate...
# Tired your more poor be happy a delight end date...
# Doth in against they alas ever thy despised grow hill...
# Fill doctor-like not ills whole is no oaths of still...
# Love the ink in meetness never the be  meet...
# One i blunt a calls of in thy sun sweet...
# Seen sick but and my and thus on with conspire...
# What love not his self yet that but prime desire...

# %%
rhyming_sonnet = random.sample(rhyming_pairs, 14)

r1 = rhyming_sonnet[:7]
r2 = rhyming_sonnet[7:]

for i in range(3):
    a1, a2 = r1[i]
    b1, b2 = r2[i]
    print(sample_sentence1(hmm10, obs_map, a1, n_words=8))
    print(sample_sentence1(hmm10, obs_map, b1, n_words=8))
    print(sample_sentence1(hmm10, obs_map, a2, n_words=8))
    print(sample_sentence1(hmm10, obs_map, b2, n_words=8))


# printing final line of english sonnet 
a1, a2 = r1[4]
print("  " + str(sample_sentence1(hmm10, obs_map, a1, n_words=8)))
print("  " + str(sample_sentence1(hmm10, obs_map, a2, n_words=8)))
# Out:
# You doth my and got past or fair...
# Love too gentle faults in too have fade...
# Or chide torture from but most lend heir...
# His smell of thou their muses desert shade...
# Save better seeing so far my their old...
# Will lour'st weep since mine given depends pluck...
# Thee of art doth that black that cold...
# With guard frank whilst so held within luck...
# And vaunt if neck full still all cruel...
# Unless by the beauty's eye's and invention rhyme...
# Heart being gilding heart's wide well show'st fuel...
# Thee can i grace but eyes that time...
#   I excuse win poor thy true an cherish...
#   I pleasant no if viewest in thee perish...

# %%
# Training a 20-state HMM for English sonnet 

# Training HMM with 10 states on reversed text
hmm20 = unsupervised_HMM(obs, 20, 100)
# Out:
# Iteration: 10
# Iteration: 20
# Iteration: 30
# Iteration: 40
# Iteration: 50
# Iteration: 60
# Iteration: 70
# Iteration: 80
# Iteration: 90
# Iteration: 100

# %%
rhyming_sonnet = random.sample(rhyming_pairs, 14)

r1 = rhyming_sonnet[:7]
r2 = rhyming_sonnet[7:]

for i in range(3):
    a1, a2 = r1[i]
    b1, b2 = r2[i]
    print(sample_sentence1(hmm20, obs_map, a1, n_words=8))
    print(sample_sentence1(hmm20, obs_map, b1, n_words=8))
    print(sample_sentence1(hmm20, obs_map, a2, n_words=8))
    print(sample_sentence1(hmm20, obs_map, b2, n_words=8))


# printing final line of english sonnet 
a1, a2 = r1[4]
print("  " + str(sample_sentence1(hmm20, obs_map, a1, n_words=8)))
print("  " + str(sample_sentence1(hmm20, obs_map, a2, n_words=8)))
# Out:
# Summer's o you where graced complexion part weep...
# Speak have but given love so threw dimmed...
# That forward husband gluttoning did in a keep...
# The have live the didst leaves find untrimmed...
# All do grounded what that some that one...
# As thou bier i services the love prognosticate...
# Ladies so thou love that vile joy none...
# Art compared others' the doth thy bold date...
# Thy stain stealing me have shall prime sounds...
# In and see your thinks daily upon prime...
# Hear how self and he else  confounds...
# If morning the night from the see time...
#   Pent o'er drunk not for special look hill...
#   Though my full should thy love's hand still...

# %%
import random

# %% [markdown]
# # Haiku

# %%
a = "hi my name is maya"
b = a.split()
for w in reversed(b):
    print(w, end="")
# Out:
# mayaisnamemyhi

# %% [markdown]
# # Visualizations (repurpose the visualizations + word cloud code provided, and examine specific rows in the transition / observation matrix.

# %% [markdown]
# In your report, you should explain your interpretation of how a Hidden Markov Model learns patterns in Shakespeare’s texts. You should briefly elaborate on the methods you used to analyze the model. In addition, for at least 5 hidden states give a list of the top 10 words that associate with this hidden state and state any common features among these groups. Furthermore, try to interpret and visualize the learned transitions between states. A possible suggestion is to draw a transition diagram of your Markov model and give descriptive names to the states. Feel free to be creative with your visualizations, but remember that accurately representing data is still your primary objective. Your figures, tables, and diagrams should contribute to a discussion about your model.

# %% [markdown]
# # Visualizing top 10 words

# %%
state_i = np.array([10, 9, 8, 7, 6, 5])
top_10 = (state_i[np.argsort(state_i)[-3:]]) 
top_10
# Out:
# array([ 8,  9, 10])

# %%
# Training 5-stat HMM for analysis
text = open(os.path.join(os.getcwd(), 'data_Shakespeare/shakespeare.txt')).read()
obs, obs_map = parse_observations(text)

# %%
hmm5 = unsupervised_HMM(obs, 5, 100)
# Out:
# Iteration: 10
# Iteration: 20
# Iteration: 30
# Iteration: 40
# Iteration: 50
# Iteration: 60
# Iteration: 70
# Iteration: 80
# Iteration: 90
# Iteration: 100

# %%
def find_top_10(hmm, state_idx, obs_map):
    # O: Observation matrix with dimensions L x D.
    # The (i, j)^th element is the probability of
    # emitting observation j given state i.
    
    # Get reverse map
    obs_map_r = obs_map_reverser(obs_map)
    O = np.array(hmm.O)
    state_i = O[state_idx]
    #top_10 = (state_i[np.argsort(state_i)[-10:]]) 
    top_10_idx = state_i.argsort()[-15:][::-1]
    emissions = []
    for i in top_10_idx:
        emissions.append(obs_map_r[i])
        
    return emissions 

def obs_map_reverser(obs_map):
    obs_map_r = {}

    for key in obs_map:
        obs_map_r[obs_map[key]] = key

    return obs_map_r

# %%
for i in range(5):
    print("state: " + str(i) + " \n" + str(find_top_10(hmm5, i, obs_map)))
# Out:
# state: 0
# ['the', 'of', 'my', 'in', 'his', 'thy', 'all', 'their', 'by', 'and', 'to', 'is', 'this', 'on', 'be']
# state: 1
# ['my', 'and', 'that', 'a', 'to', 'the', 'for', 'with', 'thy', 'when', 'if', 'in', 'what', 'mine', 'no']
# state: 2
# ['and', 'but', 'for', 'o', 'as', 'then', 'the', 'how', 'which', 'to', 'or', 'like', 'nor', 'when', 'against']
# state: 3
# ['i', 'thou', 'me', 'thee', 'love', 'you', 'that', 'thy', 'not', 'it', 'self', 'eyes', 'your', 'they', 'he']
# state: 4
# ['to', 'and', 'with', 'of', 'so', 'that', 'in', 'is', 'are', 'which', 'have', 'as', 'doth', 'be', 'my']

# %%
wordclouds = states_to_wordclouds(hmm5, obs_map)

# %% [markdown]
# # For visualizing transitions between states

# %%
anim = animate_emission(hmm5, obs_map, M=5)
HTML(anim.to_html5_video())
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/cbook/__init__.py:424: MatplotlibDeprecationWarning:
# Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warn_deprecated("2.2", "Passing one of 'on', 'true', 'off', 'false' as a "
# Animating...
# <video width="864" height="864" controls autoplay loop>
#   <source type="video/mp4" src="...
